# %%
import warnings
import torch
import pandas as pd
from tqdm import tqdm
warnings.filterwarnings("ignore")

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("bltlab/queryner-augmented-data-bert-base-uncased")
model = AutoModelForTokenClassification.from_pretrained("bltlab/queryner-augmented-data-bert-base-uncased")

# %%
import json

with open("modified_message_contents.json") as f:
    ners = json.load(f)

with open("all_prompts.json") as f:
    prod = json.load(f)

# %%
# iterate over all prompts
data = {}
data['tokens'] = []
data['ner_tags'] = []

for _, prod_list in prod.items():
    for product in prod_list:
        data['tokens'].append(prod_list[product])

for _, ner_list in ners.items():
    for ner in ner_list:
        data['ner_tags'].append(ner_list[ner])

# %%
for i in range(len(data['tokens']) - 1, -1, -1):
    if len(data['tokens'][i]) != len(data['ner_tags'][i]):
        del data['tokens'][i]
        del data['ner_tags'][i]

# %%
len(data['tokens']), len(data['ner_tags'])
# Out:
# (14840, 14840)

# %%
# iterate over every list of ner_tags, rename some of the tags
rename_list = {
    'B-size': 'B-UoM', 
    'I-size': 'I-UoM',
    'B-intellectual_properties': 'B-content',
    'I-intellectual_properties': 'I-content'
}

for i in range(len(data['ner_tags'])):
    for j in range(len(data['ner_tags'][i])):
        if data['ner_tags'][i][j] in rename_list:
            data['ner_tags'][i][j] = rename_list[data['ner_tags'][i][j]]

# %%
model.config.label2id.keys()
# Out:
# dict_keys(['B-UoM', 'B-color', 'B-condition', 'B-content', 'B-core_product_type', 'B-creator', 'B-department', 'B-material', 'B-modifier', 'B-occasion', 'B-origin', 'B-price', 'B-product_name', 'B-product_number', 'B-quantity', 'B-shape', 'B-time', 'I-UoM', 'I-color', 'I-condition', 'I-content', 'I-core_product_type', 'I-creator', 'I-department', 'I-material', 'I-modifier', 'I-occasion', 'I-origin', 'I-price', 'I-product_name', 'I-product_number', 'I-quantity', 'I-shape', 'I-time', 'O'])

# %%
real_tags = list(model.config.label2id.keys())

# Collect indices to delete
indices_to_delete = []

for i in range(len(data['ner_tags']) - 1, -1, -1):
    for j in range(len(data['ner_tags'][i])):
        if data['ner_tags'][i][j] not in real_tags:
            print(i, data['tokens'][i], data['ner_tags'][i])
            indices_to_delete.append(i)
            break  # No need to check further if one tag is found

indices_to_delete, len(indices_to_delete)
# Out:
# 14836 ['SUUKSESS', 'Women', 'Sexy', 'Tummy', 'Control', 'One', 'Piece', 'Swimsuits', 'Halter', 'Push', 'Up', 'Bathing', 'Suits'] ['B-creator', 'B-department', 'B-modifier', 'B-feature', 'I-feature', 'B-quantity', 'I-quantity', 'B-core_product_type', 'I-core_product_type', 'B-shape', 'B-modifier', 'B-core_product_type', 'I-core_product_type']
# 14826 ['Stelle', 'Women', 'Ballet', 'Shoes', 'Highly', 'Stretch', 'Canvas', 'Adult', 'Ballet', 'Slippers', 'Split', 'Sole'] ['B-creator', 'B-department', 'B-product_type', 'I-product_type', 'B-modifier', 'B-modifier', 'B-material', 'B-department', 'I-product_type', 'I-product_type', 'B-modifier', 'B-sole_type']
# 14825 ['Egoelife', 'LB', 'BBPHF18', 'Unisex', 'Casual', 'Canvas', 'Satchel', 'Messenger', 'Bag', 'for', 'Traveling'] ['B-creator', 'B-product_number', 'I-product_number', 'B-department', 'B-intended_use', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'O', 'B-intended_use']
# 14824 ['Fashio', 'FF', 'Mens', 'Construction', 'Pants', 'Utility', 'Work', 'Heavy', 'Duty', 'Workwear', 'Trousers'] ['B-creator', 'B-product_number', 'B-department', 'B-activity', 'B-core_product_type', 'B-occasion', 'B-activity', 'B-modifier', 'B-condition', 'B-occasion', 'B-type']
# 14823 ['Emopeak', '24pcs', 'Christmas', 'Balls', 'Ornaments', 'for', 'Xmas', 'Christmas', 'Tree', 'Shatterproof'] ['B-creator', 'B-quantity', 'B-occasion', 'B-product_name', 'I-product_name', 'O', 'B-holiday', 'B-occasion', 'B-core_product_type', 'B-condition']
# 14822 ['Miluxas', 'Womens', 'Beach', 'Flip', 'Flop', 'Clearance', 'Black', '6', '37'] ['B-creator', 'B-department', 'B-occasion', 'B-product_type', 'I-product_type', 'B-condition', 'B-color', 'B-UoM', 'I-UoM']
# 14821 ['Hand', 'Painted', 'Galaxy', 'Plugs', 'Pair', 'Sizes', '8mm', 'and', 'Above'] ['B-modifier', 'I-modifier', 'B-design', 'B-core_product_type', 'B-quantity', 'B-UoM', 'I-UoM', 'O', 'B-UoM']
# 14820 ['Chef', 'Uniforms', 'Lightweight', 'Womens', '3', '4', 'Sleeve', 'w', 'Plastic', 'Buttons', 'Chef', 'Coat', 'in'] ['B-creator', 'B-core_product_type', 'B-modifier', 'B-department', 'B-UoM', 'I-UoM', 'B-part', 'O', 'B-material', 'B-product_name', 'B-creator', 'B-core_product_type', 'O']
# 14804 ['Wayabo', 'Vintage', '80s', '90s', 'Bucket', 'Hats', 'Foldable', 'for', 'Women', 'Men', 'Unisex', 'Adult', 'Summer'] ['B-creator', 'B-condition', 'B-time', 'I-time', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'O', 'B-department', 'B-department', 'B-gender', 'B-condition', 'B-occasion']
# 14787 ['Promised', 'Love', 'Diamond', 'Promise', 'Ring', '1', '5', 'ct', 'tw', 'in', 'Sterling', 'Silver', 'Sterling'] ['B-creator', 'B-content', 'B-intelectual_properties', 'B-core_product_type', 'I-core_product_type', 'B-time', 'I-time', 'B-UoM', 'I-UoM', 'O', 'B-material', 'I-material', 'I-material']
# 14780 ['Tag', 'for', 'Bracelet', 'Rectangle', 'Charm', 'Wholesale', 'Engraving', 'Custom', 'Pendant'] ['B-product_name', 'O', 'B-core_product_type', 'B-shape', 'B-intelectual_properties', 'B-modifier', 'B-occasion', 'B-modifier', 'B-core_product_type']
# 14778 ['Vintage', 'Curved', 'V', 'Shaped', 'Diamond', 'Wedding', 'Band', '14K', '18K', 'Rose', 'Gold', 'Art', 'Deco', 'Unique'] ['B-condition', 'B-shape', 'B-shape', 'I-shape', 'B-intelectual_properties', 'B-occasion', 'I-occasion', 'B-material', 'I-material', 'B-color', 'I-color', 'B-creator', 'B-origin', 'B-modifier']
# 14767 ['Little', 'Planet', 'Adult', 'Womens', 'Maternity', 'Oversized', 'Essential', 'Cardigan', 'Baby', 'Size', 'M'] ['B-creator', 'B-product_name', 'B-department', 'B-color', 'B-modifier', 'B-condition', 'B-core_product_type', 'B-protection', 'B-shape', 'B-core_product_type', 'B-UoM']
# 14766 ['Pinkblush', 'Maternity', 'Red', 'Ruffle', 'Accent', 'Maternity', 'Bikini', 'Set'] ['B-creator', 'B-department', 'B-color', 'B-design', 'B-modifier', 'B-department', 'B-core_product_type', 'B-quantity']
# 14765 ['G2F', 'Design', 'Bracelet', 'for', 'Women', '–', 'Handmade', 'Vegan', 'Boho', 'Natural', 'Stone', 'Layered'] ['B-creator', 'B-product_name', 'B-core_product_type', 'O', 'B-department', 'O', 'B-condition', 'B-material', 'B-style', 'I-style', 'I-style', 'I-style']
# 14762 ['SweatyRocks', 'Womens', 'Spot', 'Long', 'Sleeve', 'V', 'Neck', 'Blouse', 'Wrap', 'Front', 'Peplum', 'Top', 'with', 'Belt'] ['B-creator', 'B-department', 'B-modifier', 'B-UoM', 'I-UoM', 'B-shape', 'I-shape', 'B-core_product_type', 'I-core_product_type', 'B-product_name', 'I-product_name', 'I-product_name', 'O', 'B-accessories']
# 14758 ['ANIVIVO', 'Womens', 'Skorts', 'Skirts', '20', 'Knee', 'Length', 'Tennis', 'Golf', 'Pickleball', 'Sports'] ['B-creator', 'B-department', 'B-core_product_type', 'I-core_product_type', 'B-UoM', 'B-length', 'I-length', 'B-occasion', 'I-occasion', 'B-occasion', 'I-occasion']
# 14756 ['Adidas', 'Womens', 'Seamless', 'Hi', 'Leg', 'Brief', 'Panty', 'Underwear'] ['B-creator', 'B-department', 'B-modifier', 'B-product_name', 'I-product_name', 'B-core_product_type', 'B-core_product_type', 'B-product_type']
# 14739 ['Skida', 'VerMontana', 'Field', 'Winter', 'Headband'] ['B-creator', 'B-product_name', 'I-product_name', 'B-season', 'B-core_product_type']
# 14735 ['Pinkblush', 'Maternity', 'Navy', 'Blue', 'Ribbed', 'V', 'Neck', 'Ruched', 'Criss', 'Cross', 'Low', 'Back', 'Maternity'] ['B-creator', 'B-department', 'B-color', 'I-color', 'B-material', 'B-shape', 'B-shape', 'B-condition', 'B-product_name', 'I-product_name', 'B-back', 'B-back', 'I-back']
# 14697 ['Vintage', 'Style', 'Contour', 'Engagement', 'Ring', 'Guard', 'Sterling', 'Silver', 'Ring', 'Enhancer', 'with'] ['B-modifier', 'B-design', 'B-style', 'B-occasion', 'B-core_product_type', 'B-type', 'B-material', 'B-color', 'B-core_product_type', 'I-core_product_type', 'O']
# 14696 ['Ae', 'Next', 'Level', 'Low', 'Rise', 'Denim', 'Short', 'Short', 'Womens', 'Medium', 'Indigo', '4'] ['B-creator', 'B-type', 'I-type', 'B-rise', 'B-waist', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-department', 'B-color', 'I-color', 'B-UoM']
# 14695 ['Lacoste', 'Womens', 'L12D', 'Slim', 'Fit', 'Stretch', 'Mini', 'Piqué', 'Polo', '38'] ['B-creator', 'B-department', 'B-product_number', 'B-modifier', 'I-modifier', 'B-feature', 'B-design', 'B-material', 'B-core_product_type', 'B-UoM']
# 14694 ['Finetoo', 'Tummy', 'Control', 'Underwear', 'for', 'Women', 'High', 'Waisted', 'Nylon', 'Brief', 'No', 'Show', 'Womens'] ['B-creator', 'B-feature', 'I-feature', 'B-core_product_type', 'O', 'B-department', 'B-rise', 'I-rise', 'B-material', 'B-core_product_type', 'O', 'O', 'B-department']
# 14693 ['Eddie', 'Bauer', 'Womens', 'Aster', 'Sleeveless', 'Empire', 'Waist', 'Dress', 'Spice', 'Size', 'S'] ['B-creator', 'I-creator', 'B-department', 'B-product_name', 'B-style', 'B-waist', 'B-core_product_type', 'B-material', 'B-color', 'B-UoM', 'I-UoM']
# 14692 ['VmSlyii', 'Maternity', 'Summer', 'Floral', 'Midi', 'Bodycon', 'Dresses', 'Short', 'Puff', 'Sleeve', 'Square'] ['B-creator', 'B-department', 'B-time', 'B-color', 'B-UoM', 'B-modifier', 'B-core_product_type', 'B-length', 'B-shape', 'B-body_part', 'B-design']
# 14670 ['RanRui', 'Kimonos', 'for', 'Women', 'Duster', 'Kimono', 'Beach', 'Boho', 'Kimono', 'Beach', 'Cover', 'Up', 'Bathing'] ['B-creator', 'B-core_product_type', 'O', 'B-department', 'B-product_name', 'I-product_name', 'B-occasion', 'B-modifier', 'I-core_product_type', 'I-occasion', 'B-occasion', 'I-occassion', 'B-occasion']
# 14598 ['Sumolux', 'Mens', 'Newsboy', 'Cap', 'Winter', 'Beret', 'Hat', 'Cabbie', 'Flat', 'Cap'] ['B-creator', 'B-department', 'I-core_product_type', 'I-core_product_type', 'B-season', 'B-core_product_type', 'I-core_product_type', 'B-shape', 'B-shape', 'B-core_product_type']
# 14592 ['Gap', 'Womens', 'Maternity', 'Cotton', 'Nursing', 'Tank'] ['B-creator', 'B-department', 'B-occasion', 'B-material', 'B-occiption', 'B-core_product_type']
# 14573 ['SIMIYA', 'Shapewear', 'for', 'Women', 'Tummy', 'Control', 'Bodysuit', 'Extra', 'Firm', 'Body', 'Shaper'] ['B-creator', 'B-core_product_type', 'O', 'B-department', 'B-modifier', 'I-modifier', 'B-core_product_type', 'B-modifier', 'I-modifier', 'B-body_shape', 'I-body_shape']
# 14451 ['Comfort', 'Fit', 'Repurposed', 'Mid', 'Wash', 'Shorts', 'Final', 'Sale', 'Mid', 'Wash', '16'] ['B-modifier', 'B-fit', 'B-condition', 'B-color', 'B-core_product_type', 'B-color', 'B-condition', 'B-color', 'I-color', 'B-UoM', 'I-UoM']
# 14428 ['LuciaStofej', 'Peacock', 'Feather', 'Hand', 'Fan', 'Ivory', 'or', 'Real', 'Peacock', 'Art', 'Deco', 'Fan', 'Bridal'] ['B-creator', 'B-product_name', 'I-product_name', 'B-material', 'B-core_product_type', 'B-color', 'O', 'B-material', 'B-modifier', 'B-style', 'B-core_product_type', 'I-core_product_type', 'B-occasion']
# 14339 ['P', 'A', 'C', 'T', 'Womens', 'Organic', 'Everyday', 'Boy', 'Short', '6', 'Pack', 'in', 'Charcoal', 'Basics', 'Fair', 'Trade'] ['B-product_name', 'I-product_name', 'I-product_name', 'I-product_name', 'B-department', 'B-material', 'B-occasion', 'I-department', 'B-UoM', 'B-quantity', 'O', 'B-color', 'B-modifier', 'I-modifier', 'B-origin', 'B-trade']
# 14334 ['16', '189mm', 'White', 'South', 'Sea', 'Pearl', 'Necklace', 'AAAA', 'Quality', 'Venus', 'Certified'] ['B-quantity', 'B-UoM', 'B-color', 'B-origin', 'I-origin', 'B-material', 'B-core_product_type', 'B-condition', 'B-quality', 'B-product_name', 'I-product_name']
# 14331 ['Pandora', 'Love', 'You', 'Mom', 'Infinity', 'Heart', 'Charm'] ['B-creator', 'B-content', 'I-content', 'B-recipient', 'I-recipient', 'B-core_product_type', 'B-shape']
# 14322 ['Wantdo', 'Mens', 'Wool', 'Blend', 'Jacket', 'Stand', 'Collar', 'Windproof', 'Pea', 'Coat'] ['B-creator', 'B-department', 'B-material', 'I-material', 'B-core_product_type', 'B-feature', 'B-feature', 'B-modifier', 'B-origin', 'I-origin']
# 14321 ['Womens', 'Petite', 'Chlorine', 'Resistant', 'Tummy', 'Control', 'Swim', 'Skirt', 'Swim', 'Bottoms', 'Lands'] ['B-department', 'B-UoM', 'B-feature', 'I-feature', 'B-condition', 'I-condition', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'I-core_product_type', 'B-creator']
# 14319 ['Build', 'Your', 'Own', 'Cowgirl', 'Hat'] ['B-feature', 'I-feature', 'I-feature', 'B-occasion', 'B-core_product_type']
# 14318 ['Stylish', 'Art', 'Deco', 'Style', 'Earrings', 'Set', 'in', 'Bronze'] ['B-modifier', 'B-product_name', 'B-style', 'B-style', 'B-core_product_type', 'B-quantity', 'O', 'B-color']
# 14316 ['Chef', 'Uniforms', 'UA', 'Chef', 'Womens', '4', 'Pocket', 'Elastic', 'Waistband', 'Chef', 'Pants', 'in', 'Black'] ['B-creator', 'B-product_name', 'B-product_number', 'B-core_product_type', 'B-department', 'B-UoM', 'B-feature', 'B-modifier', 'B-waist', 'B-product_name', 'B-core_product_type', 'O', 'B-color']
# 14315 ['Tyhengta', 'Mens', 'Swim', 'Trunks', 'Quick', 'Dry', 'Beach', 'Shorts', 'with', 'Zipper', 'Pockets', 'and', 'Mesh', 'Lining'] ['B-creator', 'B-department', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'I-modifier', 'B-occasion', 'B-core_product_type', 'O', 'B-modifier', 'B-feature', 'O', 'B-feature', 'B-material']
# 14239 ['Hde', 'Women', 'Workout', 'Dress', 'Built', 'in', 'Shorts', 'Sleeveless', 'Athletic', 'Sport', 'Dress', 'L', 'Women'] ['B-creator', 'B-department', 'B-occasion', 'B-core_product_type', 'B-modifier', 'O', 'B-product_name', 'B-modifier', 'B-occasion', 'B-sport', 'B-core_product_type', 'B-UoM', 'B-department']
# 14227 ['Burlap', 'Life', '2024', 'New', 'Freshwater', 'Cultured', 'Aaaaa', 'Quality', 'Genuine', 'Real', 'Pearl', 'Strand'] ['B-material', 'B-product_name', 'B-time', 'B-condition', 'B-material', 'I-material', 'B-condition', 'B-quality', 'B-condition', 'I-condition', 'B-condition', 'B-modifier']
# 14222 ['Honrane', 'Removal', 'Invisible', 'Shoulder', 'Straps', 'Body', 'Shaper', 'U', 'shape', 'Backless', 'Deep', 'V'] ['B-creator', 'B-product_name', 'B-condition', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-core_product_type', 'B-shape', 'B-design', 'B-design', 'B-design', 'B-shape']
# 14219 ['Giani', 'Bernini', 'Byzantine', 'Link', 'Bracelet', 'in', 'Sterling', 'Silver', 'Created', 'for', 'Macys', 'Silver'] ['B-creator', 'I-creator', 'B-product_name', 'B-design', 'B-core_product_type', 'O', 'B-material', 'B-color', 'B-condition', 'O', 'B-creator', 'B-color']
# 14216 ['Open', 'Edit', 'Classic', 'Cool', 'Oversize', 'Pajamas', 'in', 'Blue', 'Painterly', 'Abstract', 'Floral', 'at'] ['B-modifier', 'B-creator', 'B-product_name', 'I-product_name', 'B-modifier', 'B-core_product_type', 'O', 'B-color', 'B-modifier', 'B-design', 'I-design', 'O']
# 14212 ['MAGCOMSEN', 'Mens', 'Bomber', 'Jacket', 'Warm', 'Zip', 'Up', 'Spring', 'Coat', 'Lightweight', 'Casual'] ['B-creator', 'B-department', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-core_feature', 'B-product_feature', 'B-time', 'B-core_product_type', 'B-details', 'B-occasion']
# 14211 ['Carhartt', 'Womens', 'Modern', 'Fit', 'Jogger', 'Pant', 'Grape', 'Xsp'] ['B-creator', 'B-department', 'B-modifier', 'B-sizing', 'B-core_product_type', 'I-core_product_type', 'B-color', 'B-UoM']
# 14210 ['Dillards', 'Genuine', 'Shell', 'Long', 'Pendant', 'Necklace', 'Shell', 'Gold'] ['B-creator', 'B-quality', 'B-core_product_type', 'B-length', 'B-core_product_type', 'I-core_product_type', 'B-color', 'B-color']
# 14209 ['Fruit', 'of', 'The', 'Loom', 'Womens', 'Micro', 'Waffle', 'Premium', 'Thermal', 'Union', 'Suit', 'Merlot', 'Heather'] ['B-creator', 'O', 'O', 'B-creator', 'B-department', 'B-material', 'B-details', 'B-product_quality', 'B-type', 'B-core_product_type', 'I-core_product_type', 'B-color', 'B-sku']
# 14208 ['YARBAR', 'Womens', 'Bra', 'Extender', '3', 'Hook', '2', 'Hook', 'Bra', 'Extension', 'Strap', 'Soft', 'and', 'Comfortable'] ['B-creator', 'B-department', 'B-core_product_type', 'B-product_feature', 'B-inventory', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'I-core_product_type', 'B-extension', 'B-core_product_type', 'B-detail', 'O', 'B-quality']
# 14207 ['Ann', 'Taylor', 'Petite', 'Sparkle', 'Button', 'Trim', 'Sequin', 'Tweed', 'Dress', 'Size', '00', 'Black', 'Gold', 'Womens'] ['B-creator', 'I-creator', 'B-department', 'B-modifier', 'I-core_product_type', 'B-modifier', 'B-material', 'B-color', 'B-core_product_type', 'B-UoM', 'I-inventory', 'B-color', 'I-color', 'B-department']
# 14206 ['Latuza', 'Womens', 'Flannel', 'Zipper', 'Onesie', 'Long', 'Sleeves', 'Pajama', 'Jumpsuit'] ['B-creator', 'B-department', 'B-material', 'B-core_feature', 'B-core_product_type', 'B-length', 'I-modifier', 'B-core_product_type', 'I-core_product_type']
# 14205 ['Womens', 'Slim', 'Fit', 'Active', 'Tracksuit', 'ladies', 'summer', 'jackets', 'with', 'Thumb', 'Holes', 'Long'] ['B-department', 'B-modifier', 'I-modifier', 'B-occasion', 'B-core_product_type', 'B-department', 'B-time', 'B-core_product_type', 'O', 'B-detail', 'I-product_cost', 'B-length']
# 14204 ['Yodetey', 'MenS', 'Cargo', 'Trousers', 'Work', 'Wear', 'Combat', 'Safety', 'Cargo', '6', 'Pocket', 'Full', 'Pants'] ['B-creator', 'B-department', 'B-core_product_type', 'I-core_product_type', 'B-occasion', 'I-modifier', 'I-core_product_type', 'B-modifier', 'B-core_product_type', 'B-UoM', 'I-inventory', 'B-length', 'B-core_product_type']
# 14160 ['Quilted', 'Wallet', 'Pattern', 'Quilted', 'Clutch', 'Style', 'Wallet', 'PDF', 'Download', 'Full', 'how', 'to'] ['B-modifier', 'B-core_product_type', 'B-pattern', 'I-pattern', 'B-style', 'I-style', 'I-style', 'B-product_name', 'I-product_name', 'I-product_name', 'O', 'O']
# 14156 ['MakeMeChic', 'Womens', 'Maternity', 'Solid', 'Wrap', 'Cross', 'Tee', 'Short', 'Sleeve', 'V', 'Neck', 'Casual', 'Tops'] ['B-creator', 'B-department', 'B-occasion', 'B-color', 'B-style', 'I-style', 'B-core_product_type', 'B-UoM', 'I-UoM', 'B-shape', 'I-shape', 'B-occasion', 'B-core_product_type']
# 14072 ['AIEGNOS', '925', 'Sterling', 'Silver', 'Charms', 'for', 'European', 'Snake', 'Charm', 'Bracelet', 'Necklace', 'for'] ['B-creator', 'B-material', 'I-material', 'I-material', 'B-core_product_type', 'O', 'B-origin', 'B-core_product_type', 'B-material', 'B-feature', 'B-core_product_attributive_term', 'O']
# 14070 ['Under', 'Armour', 'Mens', 'Micro', 'G', 'Valsetz', 'Trek', 'Mid', 'Leather', 'Waterproof', 'Tactical', 'Boots'] ['B-creator', 'I-creator', 'B-department', 'B-product_name', 'B-product_number', 'I-product_number', 'B-product_name', 'B-color', 'B-condition', 'B-feature', 'B-occasion', 'B-core_product_for_time']
# 14068 ['Custom', 'High', 'Polished', 'Solid', 'Grillz', 'Free', 'permanent', 'cuts', 'Free', 'Mold', 'kits'] ['B-condition', 'B-modifier', 'I-modifier', 'B-color', 'B-core_product_type', 'O', 'B-condition', 'B-feature', 'O', 'B-creator', 'I-department']
# 14065 ['Olivia', 'Bottega', 'Lace', 'Wedding', 'Dress', 'OB7962', 'Whole', 'with', 'Long', 'Sleeves', 'Made', 'to', 'Order'] ['B-creator', 'I-creator', 'B-material', 'B-occasion', 'B-core_product_type', 'B-product_number', 'B-quantity', 'O', 'B-modifier', 'B-feature', 'B-origin', 'O', 'O']
# 14064 ['Autumn', 'fall', 'leaf', 'arm', 'cuff', 'arm', 'wrap', 'autumn', 'woodland', 'fairy', 'mother', 'nature', 'costume'] ['B-occasion', 'I-occasion', 'B-content', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'B-occasion', 'B-occasion', 'B-occasion', 'B-occasion', 'B-relationship', 'B-content', 'B-core_product_type']
# 14063 ['HAIX', 'Fire', 'Flash', 'Xtreme', 'Womens', '506006', '6', 'Wide'] ['B-creator', 'B-product_name', 'I-product_name', 'I-product_name', 'B-department', 'B-product_number', 'B-UoM', 'B-fit']
# 14062 ['Mizuno', 'Womens', 'Wave', 'Dimension', 'Volleyball', 'Shoe', '105', 'White', 'Rose', 'Gold', '007e'] ['B-creator', 'B-department', 'B-product_name', 'B-product_id', 'B-sport', 'B-core_product_type', 'B-product_number', 'B-color', 'I-color', 'B-color', 'B-product_number']
# 14060 ['Kojooin', 'Womens', 'Maternity', 'Square', 'Neck', 'Short', 'Sleeve', 'Summer', 'Dress', 'Smocked', 'Boho'] ['B-creator', 'B-department', 'B-department', 'B-shape', 'B-part', 'B-part', 'B-part', 'B-season', 'B-core_product_type', 'B-style', 'B-style']
# 14059 ['Chuarry', '4', 'Pair', 'Elastic', 'Thigh', 'Bands', 'L', 'Size', 'Leg', 'Comfort', 'Nylon', 'Lined', 'Protector', 'Skin'] ['B-creator', 'B-quantity', 'I-quantity', 'B-material', 'B-part', 'B-part', 'B-UoM', 'B-UoM', 'B-part', 'B-modifier', 'B-material', 'I-material', 'B-modifier', 'B-core_product_type']
# 14058 ['Mens', '3', 'Piece', 'Slim', 'Fit', 'Suit', 'Jacket', 'Vest', 'Suit', 'Pants', 'Single', 'Breasted', 'Vintage', 'Suits'] ['B-department', 'B-quantity', 'I-quantity', 'B-fit', 'I-fit', 'B-core_product_type', 'I-core_product_type', 'I-core_product_type', 'I-core_product_type', 'B-core_product_type', 'B-closure', 'B-modifier', 'B-style', 'B-department']
# 14055 ['Fancy', 'Shiny', 'Boho', 'Leather', 'Wrap', 'Bracelets', 'Trendy', 'Layered', 'Bracelets', 'with', 'Magnetic'] ['B-modifier', 'B-modifier', 'B-style', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-style', 'I-core_product_type', 'O', 'B-closure']
# 14050 ['niaahinn', 'Scrubs', 'Set', 'for', 'Women', 'Nurse', 'Uniform', 'Jogger', 'Suit', 'Stretch', 'Top', 'Pants', 'with'] ['B-creator', 'B-core_product_type', 'B-modifier', 'O', 'B-department', 'B-occupation', 'B-core_product_type', 'B-modifier', 'B-core_product_type', 'I-material', 'B-core_product_type', 'O', 'O']
# 13991 ['CAZYTOYZ', 'Balaclava', 'Windproof', 'Winter', 'Face', 'Mask', 'Warm', 'Fleece', 'Ski', 'Mask', 'for', 'Men', 'and'] ['B-creator', 'B-core_product_type', 'B-modifier', 'B-time', 'B-part', 'B-core_product_type', 'B-condition', 'B-material', 'B-occasion', 'I-core_product_type', 'O', 'B-department', 'I-department']
# 13972 ['Ae', 'Next', 'Level', 'Festival', 'Flare', 'Jean', 'Womens', 'Light', 'Destroy', 'Wash', '14', 'X', 'Short'] ['B-creator', 'B-condition', 'B-quality', 'B-occasion', 'B-style', 'B-core_product_type', 'B-department', 'B-color', 'I-material', 'B-product_name', 'B-UoM', 'I-UoM', 'I-UoM']
# 13964 ['Baleaf', 'Womens', 'Tennis', 'Skirts', 'Golf', 'Skorts', 'Lightweight', 'Athletic', 'Skirts', 'with', 'Shorts'] ['B-creator', 'B-department', 'B-product_name', 'B-occasion', 'B-product_name', 'B-style', 'B-modifier', 'B-occasion', 'B-core_product_type', 'O', 'B-creator']
# 13963 ['Zip', 'Hers', 'Fit', 'Leisure', 'Elite', 'Adaptive', 'Tights', 'L'] ['B-modifier', 'B-creator', 'B-style', 'B-occasion', 'B-creator', 'B-modifier', 'B-core_product_type', 'B-UoM']
# 13962 ['Lems', 'Primal', '2', 'Mens', 'Barefoot', 'Shoes', 'Minimalist', 'Zero', 'Drop', 'Wide', 'Toe', 'Olive', '3'] ['B-creator', 'B-product_name', 'I-product_name', 'B-department', 'B-style', 'B-core_product_type', 'B-product_name', 'I-product_name', 'I-product_name', 'B-modifier', 'I-product_name', 'B-color', 'B-quantity']
# 13958 ['Womens', 'Hipster', 'Medium', 'Coverage', 'Bikini', 'Bottom', 'Shade', 'Shore', 'White', 'XL'] ['B-department', 'B-style', 'B-UoM', 'B-modifier', 'B-core_product_type', 'I-core_product_type', 'B-creator', 'B-shape', 'B-color', 'B-UoM']
# 13947 ['CRZ', 'Yoga', 'Womens', 'Racerback', 'Bikini', 'Tops', 'Quick', 'Dry', 'Modest', 'Swimsuit', 'Top', 'Sports'] ['B-creator', 'B-product_name', 'B-department', 'B-shape', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-condition', 'B-occasion', 'B-core_product_type', 'I-core_product_type', 'B-sport']
# 13912 ['Style', 'Co', 'Addyy', 'Extra', 'Wide', 'Calf', 'Dress', 'Boots', 'Created', 'for', 'Macys', 'Black', 'Smooth'] ['B-modifier', 'B-core_product_type', 'B-product_name', 'B-UoM', 'I-UoM', 'B-calves', 'B-core_product_type', 'B-occasion', 'B-modifier', 'O', 'B-creator', 'B-color', 'I-modifier']
# 13909 ['Stunning', 'Traditional', 'Indian', 'Toe', 'Rings'] ['B-modifier', 'B-core_product_type', 'B-origin', 'B-body_part', 'B-core_product_type']
# 13908 ['5', 'Pack', 'Men’s', 'Active', 'Quick', 'Dry', 'Crew', 'Neck', 'T', 'Shirts', 'Athletic', 'Running', 'Gym', 'Workout'] ['B-quantity', 'I-quantity', 'B-department', 'B-modifier', 'B-modifier', 'B-condition', 'B-shape', 'B-neck_type', 'B-product_name', 'I-product_name', 'B-occasion', 'B-activity', 'B-occuption', 'B-modifier']
# 13889 ['DELIMIRA', 'Womens', 'Tummy', 'Control', 'Shapewear', 'Thigh', 'Slimmer', 'Shorts', 'High', 'Waist'] ['B-creator', 'B-department', 'B-modifier', 'I-modifier', 'B-core_product_type', 'B-body_part', 'B-core_product_type', 'B-core_product_type', 'B-modifier', 'B-creator']
# 13874 ['ANRABESS', 'Womens', 'Crewneck', 'Long', 'Sleeve', 'Oversized', 'Fuzzy', 'Knit', 'Chunky', 'Warm', 'Pullover'] ['B-creator', 'B-department', 'B-neckline', 'B-modifier', 'B-modifier', 'B-UoM', 'B-condition', 'B-material', 'I-material', 'O', 'B-modifier']
# 13872 ['Women', 'Aa2', 'Black', 'Tan', 'Taupe', 'Pointed', 'Wrap', 'Lace', 'Up', 'Ballet', 'Flats'] ['B-department', 'B-product_number', 'B-color', 'B-color', 'B-color', 'B-shape', 'B-product_name', 'B-pattern', 'B-style', 'B-occasion', 'B-core_product_type']
# 13870 ['Baffin', 'Premium', 'Worker', 'Hi', 'Vis', 'Work', 'Boots', 'Brown', '8'] ['B-creator', 'B-quality', 'B-core_product_type', 'B-modifier', 'B-occasion', 'B-attribute', 'B-core_product_type', 'I-color', 'B-UoM']
# 13868 ['Aoysky', 'Sweater', 'Vest', 'Womens', 'V', 'Neck', 'Sweater', 'Tank', 'Tops', 'Pullover', 'Cable', 'Knit', 'Vest'] ['B-creator', 'B-core_product_type', 'I-core_product_type', 'B-department', 'B-shape', 'B-neckline', 'B-core_product_type', 'I-core_product_type', 'B-department', 'B-modifier', 'B-pattern', 'B-material', 'I-core_product_type']
# 13836 ['Gildan', 'Womens', 'Softstyle', 'Cotton', 'T', 'Shirt', 'Style', 'G64000l', 'Multipack'] ['B-creator', 'B-department', 'B-product_name', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-style', 'B-product_number', 'B-quantity']
# 13653 ['Jacaranda', 'Burgundy', 'Sexy', 'Crochet', 'Monokini', 'Scrunch', 'Bottom', 'One', 'Piece', 'Swimsuit'] ['B-creator', 'B-color', 'B-modifier', 'B-material', 'B-core_product_type', 'B-modifier', 'B-product_name', 'B-type', 'B-core_product_type', 'B-core_product_type']
# 13647 ['Dream', 'Pairs', 'Womens', 'Mid', 'Calf', 'Boots', 'Zipper', 'Leather', 'Combat', 'Boots', 'Flat', 'Buckle', 'Shoes'] ['B-product_name', 'I-product_name', 'B-department', 'B-UoM', 'I-UoM', 'B-core_product_type', 'B-modifier', 'B-material', 'B-occiption', 'I-core_product_type', 'B-shape', 'B-modifier', 'B-core_product_type']
# 13627 ['Color', 'Me', 'A', 'Season', 'Color', 'Fan', 'Summer'] ['B-content', 'I-content', 'O', 'B-time', 'B-content', 'I-content', 'B-season']
# 13582 ['Cnkwei', 'Womens', 'Casual', 'Blazers', 'Open', 'Front', 'Long', 'Sleeve', 'Lapel', 'Collar', 'Work', 'Office', 'Jacket'] ['B-creator', 'B-department', 'B-modifier', 'B-core_product_type', 'I-core_product_type', 'B-material', 'B-product_name', 'I-product_name', 'B-shape', 'I-shape', 'B-occasion', 'B-office', 'B-core_product_type']
# 13476 ['TOPMELON', 'Leather', 'Corset', 'Underbust', 'Steampunk', 'Corset', 'Top', 'Women', 'Fashion', 'Steel', 'Boned'] ['B-creator', 'B-material', 'B-core_product_type', 'B-part_name', 'B-modifier', 'I-core_product_type', 'B-content', 'B-department', 'B-content', 'B-material', 'I-part_name']
# 13466 ['Body', 'Wrappers', 'Padded', 'Bust', 'Convertible', 'Bra'] ['B-creator', 'I-creator', 'B-modifier', 'B-body_part', 'B-modifier', 'B-product_name']
# 13458 ['Virani', 'Jewelers', '18K', 'Gold', 'Diamond', 'Jewelry', 'Set', '664gm'] ['B-creator', 'I-creator', 'B-material', 'I-material', 'B-product_name', 'I-product_name', 'B-core_product_type', 'B-weight']
# 13457 ['Frankies', 'Bikinis', 'Katarina', 'Plissé', 'Cheeky', 'Bikini', 'Bottom', 'Black'] ['B-creator', 'I-creator', 'B-product_name', 'I-product_name', 'B-style', 'I-core_product_type', 'B-core_product_type', 'B-color']
# 13452 ['Edvivi', 'Ella', '52', 'in', 'Indoor', 'Matte', 'Black', 'Glam', 'Ceiling', 'Fan', 'with', 'Crystal', 'Light', 'Kit', 'and'] ['B-creator', 'B-product_name', 'B-UoM', 'I-UoM', 'B-occasion', 'B-modifier', 'B-color', 'B-style', 'I-style', 'B-core_product_type', 'O', 'B-content', 'I-content', 'B-quantity', 'I-quantity']
# 13417 ['Hongmeru', 'Purse', 'Organizer', 'Insert', 'for', 'Handbags', 'Tote', 'Bag', 'Organizer', 'Insert', 'with', '11'] ['B-creator', 'B-core_product_type', 'B-modifier', 'B-object_type', 'B-structure', 'B-core_product_type', 'B-core_product_type', 'B-core_product_type', 'B-core_product_type', 'O', 'B-structure', 'I-structure']
# 13416 ['ETRONIK', 'Weekender', 'Bag', 'with', 'Crossbody', 'Bag', 'Large', 'Travel', 'Duffle', 'Bag', 'with', 'Shoe'] ['B-creator', 'B-product_name', 'B-core_product_type', 'O', 'B-core_product_name', 'B-UoM', 'I-UoM', 'B-quantity', 'I-category', 'B-activity_area', 'B-insertable_type_id', 'O']
# 13415 ['Fitted', 'Toe', 'Rings'] ['B-fitness_type', 'B-body_part', 'B-insertable_type_modification']
# 13414 ['Black', 'Adjustable', 'Spreader', 'Bar', 'Set', 'with', '4', 'Adjustable', 'PU', 'Pink', 'Straps', 'Sports'] ['B-color', 'B-modifier', 'B-core_product_type', 'B-quantity', 'O', 'B-quantity', 'I-quantity', 'B-material', 'B-color', 'B-material', 'B-department', 'B-place']
# 13413 ['Men', 'Double', 'breasted', 'Wool', 'Cashmere', 'Great', 'Coat', 'Long', 'Overcoat', 'Heavy'] ['B-department', 'B-structure', 'I-structure', 'B-material', 'I-material', 'B-condition', 'B-core_product_type', 'B-modifier', 'B-core_product_type', 'B-core_product_type']
# 13411 ['Renee', 'C', 'Hooded', 'Longline', 'Cardigan', 'in', 'Olive', 'at', 'Nordstrom', 'Rack', 'Size', 'X', 'Large'] ['B-creator', 'I-creator', 'B-modifier', 'B-modifier', 'B-core_product_type', 'O', 'B-color', 'O', 'B-origin', 'B-place', 'B-UoM', 'O', 'B-UoM']
# 13410 ['Passionate', 'Kays', 'Heart', 'Pattern', 'Mesh', 'Underwire', 'Lingerie', 'Set', 'Red', '1XL'] ['B-modifier', 'B-creator', 'B-shape', 'B-material', 'B-modifier', 'B-structure', 'B-department', 'B-quantity', 'B-color', 'B-UoM']
# 13408 ['50pcs', 'Gauges', 'Kit', 'Ear', 'Stretching', '14G', '00G', 'Tunnel', 'Plug', 'Taper', 'Set', 'Ear', 'Gauges', 'Expander'] ['B-quantity', 'B-core_product_type', 'I-core_product_type', 'B-body_part', 'B-modifier', 'B-UoM', 'I-UoM', 'B-insertable_type_modification', 'I-insertable_type_modification', 'I-insertable_type_modification', 'B-quantity', 'B-body_part', 'B-core_product_type', 'B-material']
# 13407 ['FLYOW', 'Long', 'Chain', 'Dainty', 'Lariat', 'Necklace', 'Simple', 'Style', '925', 'Sterling', 'Silver', 'Heart'] ['B-creator', 'B-product_name', 'I-product_name', 'B-product_name', 'I-product_name', 'B-core_product_type', 'B-modifier', 'B-style', 'B-origin', 'B-material', 'I-material', 'B-shape']
# 13278 ['14K', 'Solid', 'Gold', 'Personalized', 'Bar', 'Tag', 'Pendant', 'Only', 'Vertical', 'Bars', 'Charms', 'Only'] ['B-quantity', 'B-color', 'B-material', 'B-creator', 'B-product_name', 'I-product_name', 'B-core_product_type', 'O', 'B-core_product_type', 'B-shape', 'B-shape', 'B-product_type']
# 13277 ['Rose', 'Quartz', 'Crystal', 'Anklet', 'Yoga', 'Beaded', 'Ankle', 'Bracelet', 'Healing', 'Crystal', 'Jewelry'] ['B-creator', 'B-color', 'B-material', 'B-core_product_type', 'B-occasion', 'B-product_name', 'B-core_product_type', 'B-core_product_type', 'B-modifier', 'B-color', 'B-product_type']
# 13168 ['Blank', 'Snapback', 'Hats', 'BK', 'Caps', 'Flat', 'Bill', 'Plain', 'Vintage', 'Snapbacks', 'with', 'Same', 'Color'] ['B-product_name', 'B-shape', 'B-core_product_type', 'B-product_number', 'B-product_name', 'B-shape', 'B-product_name', 'B-modifier', 'I-condition', 'B-origin', 'B-fit', 'I-fit', 'B-color']
# 13164 ['Indigo', 'Blue', 'Secret', 'Fit', 'Belly', 'Skinny', 'Maternity', 'Ankle', 'Jeggings', 'Black', 'Large'] ['B-color', 'I-color', 'B-modifier', 'B-product_name', 'B-fit', 'B-product_name', 'B-department', 'B-product_name', 'B-core_product_type', 'B-color', 'B-UoM']
# 13122 ['Art', 'Unibnive', 'Color', 'octopus', 'earplug', '6', 'types', 'set', 'full', 'co'] ['B-creator', 'B-intelectual_properties', 'B-color', 'B-core_product_type', 'I-core_product_type', 'B-quantity', 'I-quantity', 'B-modifier', 'B-origin', 'O']
# 13109 ['Solid', 'Gold', 'Grillz'] ['B-modifier', 'B-color', 'B-core_product_for']
# 13108 ['Vtg', 'Victorian', 'Style', 'Black', 'Boot', '5m', 'Leather', 'Goth', 'Steampunk', 'Lace', 'Ankle'] ['B-condition', 'B-creator', 'B-modifier', 'B-color', 'B-core_product_type', 'B-UoM', 'B-material', 'B-occasion', 'B-origin', 'B-part', 'B-part']
# 13107 ['PEGENO', 'Mens', 'Fuzzy', 'Sherpa', 'Hoodie', 'Pullover', 'Sweatshirts', 'Loose', 'Cozy', 'Pocket', 'Long'] ['B-creator', 'B-department', 'B-material', 'I-material', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'B-modifier', 'B-condition', 'B-part', 'B-modifier']
# 13105 ['Adjustable', 'Elastics', 'Band', 'Compatible', 'with', 'Apple', 'Watch', '38mm', '40mm', '41mm', '42mm', '44mm'] ['B-modifier', 'B-material', 'B-core_product_type', 'B-creator', 'O', 'B-part', 'I-part', 'B-UoM', 'I-UoM', 'I-UoM', 'I-UoM', 'B-UoM']
# 13101 ['Vamtac', 'Oversized', 'Cable', 'Knit', 'Sweaters', 'Long', 'Sleeve', 'Loose', 'Casual', 'Pullover', 'Sweater'] ['B-creator', 'B-UoM', 'B-material', 'I-material', 'B-core_product_type', 'B-modifier', 'B-part_type', 'B-UoM', 'B-occasion', 'B-modifier', 'B-material']
# 13094 ['Boho', 'Stone', 'Huggie', 'Earrings', 'by', 'Anthropologie', 'in', 'Mint', 'Womens'] ['B-style', 'B-product_name', 'I-product_name', 'B-core_product_type', 'O', 'B-creator', 'O', 'B-condition', 'B-department']
# 13093 ['Kafeimali', 'Women', 'Bohemian', 'Cotton', 'Linen', 'Double', 'Layer', 'Elastic', 'Waist', 'Long', 'Maxi', 'Skirt'] ['B-creator', 'B-department', 'B-style', 'B-material', 'I-material', 'B-quantity', 'B-modifier', 'I-modifier', 'B-modifier', 'B-UoM', 'B-core_product_type', 'I-core_product_type']
# 13062 ['Montelle', 'Intimates', 'V', 'Neck', 'Full', 'Length', 'Slip', '9500', 'Neutral', 'XL'] ['B-creator', 'B-department', 'B-shape', 'I-shape', 'B-UoM', 'B-length', 'B-core_product_type', 'B-product_number', 'B-color', 'B-UoM']
# 13049 ['Bhome', 'Maternity', 'Pants', 'for', 'Work', 'Bootcut', 'Over', 'Bump', 'Professional', 'Office', 'Long', 'Pants'] ['B-creator', 'B-department', 'B-core_product_type', 'O', 'B-occasion', 'B-style', 'B-fit', 'B-waist', 'B-occasion', 'I-occasion', 'B-length', 'I-core_product_type']
# 13048 ['Adornia', 'Freshwater', 'Pearl', 'and', 'Crystal', 'Drop', 'Earrings', 'Silver', 'White'] ['B-creator', 'B-material', 'I-material', 'O', 'B-material', 'B-design_pattern', 'B-core_product_type', 'I-material', 'B-color']
# 13047 ['Under', 'Armour', 'Womens', 'Glyde', '20', 'RM', 'Softball', 'Cleats', 'White', 'Pink'] ['B-creator', 'I-creator', 'B-department', 'B-product_name', 'B-product_number', 'B-product_number', 'B-sport', 'B-core_product_type', 'B-color', 'I-color']
# 13046 ['YESNO', 'Women', 'Sweater', 'Graphic', 'Oversized', 'Pullover', 'Sweaters', 'Casual', 'Loose', 'Long', 'Sleeve'] ['B-creator', 'B-department', 'B-core_product_type', 'B-design_pattern', 'B-UoM', 'I-clothing', 'B-core_product_type', 'B-occasion', 'B-fit', 'B-length', 'B-feature']
# 13045 ['Wilson', 'Womens', 'Profile', 'SGI', 'Complete', 'Golf', 'Set'] ['B-creator', 'B-department', 'B-product_name', 'I-product_name', 'B-completeness', 'B-core_product_type', 'I-core_product_type']
# 13044 ['Ladiyo', 'Womens', 'Classic', 'Coat', 'Lapel', 'Collar', 'Open', 'Front', 'Belted', 'Long', 'Jacket'] ['B-creator', 'B-department', 'B-style', 'B-core_product_type', 'B-feature', 'I-feature', 'B-feature', 'I-feature', 'B-modifier', 'B-length', 'B-core_product_type']
# 13040 ['Amethyst', 'Ring', 'Wrap', 'Amethyst', 'Ring', 'Gaurd', 'Customizable', 'Ring', 'Enhancer', 'Moissanite'] ['B-content', 'B-core_product_type', 'B-modifier', 'B-content', 'I-content', 'B-part', 'B-condition', 'B-core_product_type', 'B-function', 'B-content']
# 13038 ['Old', 'Navy', 'Womens', 'Maternity', 'Rollover', 'Waist', 'Linen', 'Blend', 'Shorts', '35', 'inch', 'Inseam'] ['B-creator', 'B-modifier', 'B-department', 'B-core_product_type', 'B-part', 'B-modifier', 'B-material', 'I-material', 'B-core_product_type', 'B-dimension', 'B-core_product_type', 'I-core_product_type']
# 13037 ['Pinkblush', 'Maternity', 'Cream', 'Crochet', 'Knit', 'Maternity', 'Swim', 'Cover', 'Up'] ['B-creator', 'B-department', 'B-color', 'B-material', 'B-modifier', 'B-department', 'B-core_product_type', 'B-part', 'B-modifier']
# 13036 ['Kojooin', 'Womens', 'Maternity', 'Square', 'Neck', 'Short', 'Sleeve', 'Summer', 'Dress', 'Smocked', 'Boho'] ['B-creator', 'B-department', 'B-modifier', 'B-shape', 'I-shape', 'B-part', 'I-part', 'B-time', 'B-core_product_type', 'I-core_product_type', 'B-modifier']
# 13033 ['Adidas', 'Underwear', 'Performance', 'X', 'Large', '3', 'Pack', '3', 'briefs'] ['B-creator', 'B-core_product_type', 'B-modifier', 'I-modifier', 'B-UoM', 'B-quantity', 'B-packaging', 'O', 'B-core_product_type']
# 13032 ['Chunky', 'Knit', 'Shrug', 'Customizable', 'Colour', 'Knit', 'Sleeve', 'Unique', 'Wool', 'Merino', 'Wool'] ['B-modifier', 'I-modifier', 'B-core_product_type', 'B-condition', 'B-color', 'I-modifier', 'B-part', 'B-modifier', 'B-material', 'I-material', 'B-material']
# 13021 ['Andalinge', 'Waist', 'Trainer', 'for', 'Women', 'Lower', 'Belly', 'Fat', 'Hourglass', 'Body', 'Shaper', 'Waist'] ['B-creator', 'B-core_product_type', 'I-core_product_type', 'O', 'B-department', 'B-body_part', 'B-modifier', 'B-shape', 'B-core_product_type', 'B-shape', 'B-core_product_type', 'B-modifier']
# 13020 ['Dream', 'Satin', 'Pocket', 'Sleep', 'T', 'Shirt', 'Gown', 'in', 'Black', 'Size', '22', '24', 'Plus', 'Size'] ['B-content', 'B-material', 'B-feature', 'B-occasion', 'B-core_product_type', 'B-core_product_type', 'B-core_product_type', 'O', 'B-color', 'B-UoM', 'I-UoM', 'B-UoM', 'I-UoM', 'I-UoM']
# 13019 ['Prettylittlething', 'Womens', 'Maternity', 'Grey', 'Wide', 'Leg', 'Pj', 'Pants', 'Size', 'M'] ['B-creator', 'B-department', 'B-condition', 'B-color', 'B-UoM', 'I-UoM', 'B-product_type', 'B-core_product_type', 'B-UoM', 'I-UoM']
# 13017 ['Womens', 'Nursing', 'Friendly', 'Rash', 'Guard', 'UPF', '50', 'Orchid', 'Tie', 'Dye', 'by', 'Calypsa'] ['B-department', 'B-modifier', 'B-condition', 'B-core_product_type', 'B-feature', 'B-feature_value', 'I-feature_value', 'B-color', 'B-modifier', 'B-feature', 'O', 'B-creator']
# 13015 ['JASAMBAC', 'Womens', '3', 'Piece', 'Rash', 'Guard', 'Long', 'Sleeve', 'Swimsuits', 'with', 'Boyshorts', 'Zip', 'Up'] ['B-creator', 'B-department', 'B-quantity', 'I-quantity', 'B-core_product_type', 'B-modifier', 'I-modifier', 'B-modifier', 'B-core_product_type', 'O', 'B-feature', 'B-condition', 'B-core_product_type']
# 13013 ['Large', 'Sizes', 'big', 'Ear', 'Stretching', 'Kit', 'ear', 'Tapers', 'plugs', 'choose', 'Sizes', 'Up'] ['B-UoM', 'I-UoM', 'B-modifier', 'B-body_part', 'B-modifier', 'B-core_product_type', 'B-body_part', 'B-core_product_type', 'I-core_product_type', 'O', 'B-UoM', 'I-UoM']
# 12981 ['Winter', 'Warm', 'Fleece', 'Pantyhose', 'Lined', 'Natural', 'Skin', 'Color', 'Leggings', 'Slim', 'Stretchy'] ['B-time', 'I-time', 'B-material', 'B-core_product_type', 'B-condition', 'B-color', 'B-color', 'B-color', 'B-core_product_type', 'B-modifier', 'B-conditioning']
# 12980 ['Mondo', 'Designs', '2', 'in', '1', 'ID', 'Badge', 'Holder', 'Lanyard', 'Wallet', 'Multi', 'Use', 'Womens', 'Small'] ['B-creator', 'B-content', 'B-quantity', 'I-integer', 'O', 'O', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'B-core_product_type', 'B-content', 'B-department', 'B-time', 'B-UoM']
# 12972 ['BVLA', 'BVLA', '18g', 'yellow', 'gold', '35', 'Firenze', 'nostril', 'screw', 'with', '15', 'white', 'sapphire'] ['B-creator', 'I-creator', 'B-UoM', 'B-color', 'I-color', 'B-number', 'B-product_number', 'B-core_product_type', 'I-core_product_type', 'O', 'B-integer', 'B-color', 'B-product_name']
# 12891 ['Zxzy', 'Women', 'Casual', 'Sleeveless', 'Open', 'Front', 'Tunic', 'Vest', 'Long', 'Cardigan', 'Tops', 'Coat'] ['B-creator', 'B-department', 'B-attribute', 'B-core_product_type', 'B-attribute', 'B-shape', 'B-core_product_type', 'B-core_product_type', 'B-attribute', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type']
# 12890 ['No', 'Boundaries', '5', 'Pack', 'Micro', 'Hipster', 'Womens', 'Size', 'Small', 'Multicolor'] ['B-creator', 'B-creator', 'B-number', 'B-quantity', 'B-material', 'B-core_product_type', 'B-department', 'B-UoM', 'I-UoM', 'B-color']
# 12889 ['Genuine', 'H', 'Link', 'Shark', 'Mesh', '316L', 'Stainless', 'Watch', 'Strap', 'Polished', '22mm'] ['B-condition', 'B-creator', 'B-attribute', 'B-core_product_type', 'B-material', 'B-number', 'B-material', 'B-core_product_type', 'B-attribute', 'B-UoM', 'I-UoM']
# 12888 ['Cozy', 'Netted', 'Knit', 'Arm', 'Warmer', 'in', 'Ivory', 'Womens', 'at', 'Urban', 'Outfitters'] ['B-attribute', 'B-attribute', 'B-material', 'B-attribute', 'B-core_product_type', 'O', 'B-color', 'B-department', 'O', 'B-creator', 'I-creator']
# 12887 ['NNG', 'Women', 'Over', 'The', 'Knee', 'Boots', 'Thigh', 'High', 'Suede', 'Block', 'Winter', 'Low', 'Above', 'Flat', 'Long'] ['B-creator', 'B-department', 'B-attribute', 'B-attribute', 'B-attribute', 'B-core_product_type', 'B-attribute', 'I-attribute', 'B-material', 'B-attribute', 'B-season', 'B-attribute', 'B-attribute', 'B-shape', 'B-attribute']
# 12886 ['Prada', 'Womens', 'Re', 'Nylon', 'Mittens', 'Black', 'Size', '65'] ['B-creator', 'B-department', 'B-attribute', 'B-material', 'B-core_product_type', 'B-color', 'B-UoM', 'I-UoM']
# 12885 ['Chums', 'Original', 'Cotton', 'Retainer', 'Unisex', 'Eyewear', 'Keeper', 'for', 'Sunglasses'] ['B-creator', 'B-attribute', 'B-material', 'B-core_product_type', 'B-department', 'B-core_product_type', 'B-purpose', 'O', 'B-core_product_type']
# 12884 ['ASOS', 'Design', 'Maternity', 'Ultimate', 'Skinny', 'Jeans', 'in', 'Authentic', 'Mid', 'Blue', 'with', 'Under', 'The'] ['B-creator', 'B-attribute', 'B-department', 'B-core_product_type', 'B-attribute', 'B-core_product_type', 'O', 'B-attribute', 'B-color', 'I-color', 'O', 'B-attribute', 'O']
# 12883 ['Nike', 'Legend', 'Essential', '2', 'Womens', 'Cross', 'Training', 'Shoes', 'Size', '65', 'Natural'] ['B-creator', 'B-core_product_type', 'I-core_product_type', 'B-mod(number or size)', 'B-department', 'B-attribute', 'I-attribute', 'B-core_product_type', 'B-UoM', 'I-UoM', 'B-color']
# 12882 ['OUGES', 'Womens', 'Maternity', 'Tunics', 'Tops', 'Shirts', 'Long', 'Sleeve', 'Wrap', 'V', 'Neck', 'Nursing'] ['B-creator', 'B-department', 'B-department', 'B-core_product_type', 'I-core_product_type', 'I-core_product_type', 'B-attribute', 'I-attribute', 'B-shape', 'B-shape', 'B-attribute', 'B-purpose']
# 12871 ['Calia', 'Womens', 'Cold', 'Dash', 'Run', 'Vest', 'Large', 'Rocky', 'Mountain', 'Brown'] ['B-creator', 'B-department', 'B-modifier', 'B-product_name', 'I-product_name', 'B-core_product_type', 'B-UoM', 'B-use', 'B-origin', 'B-color']
# 12870 ['BOSTANTEN', 'Women', 'Leather', 'Wallet', 'Purse', 'Long', 'Credit', 'Card', 'Cash', 'Holder', 'Organizer', 'Coffee'] ['B-creator', 'B-department', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-use', 'I-use', 'B-use', 'I-use', 'I-use', 'B-color']
# 12868 ['Holzlrgus', 'Rfid', 'Blocking', 'Aluminum', 'Wallet', 'Waterproof', 'Durable', 'and', 'Secure', 'Credit'] ['B-creator', 'B-condition', 'B-modifier', 'B-material', 'B-core_product_type', 'B-modifier', 'B-condition', 'O', 'B-condition', 'B-use']
# 12866 ['FANCYHandFans', 'Tribal', 'Art', 'Striking', 'African', 'Style', 'Multicolored', 'Folding', 'Hand', 'Fan'] ['B-creator', 'B-style', 'B-product_name', 'B-condition', 'B-origin', 'B-shape', 'B-color', 'B-modifier', 'B-core_product_type', 'I-core_product_type']
# 12862 ['Vintage', 'Zina', 'Sterling', 'Silver', 'Choker', 'Collar', 'Necklace', 'Modernist', 'Silver'] ['B-condition', 'B-creator', 'B-material', 'I-material', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'B-style', 'I-material']
# 12855 ['Amazon', 'Essentials', 'Womens', 'Lightweight', 'Waffle', 'Full', 'Length', 'Robe', 'Available', 'in', 'Plus'] ['B-creator', 'I-creator', 'B-department', 'B-product_name', 'I-product_name', 'I-product_name', 'B-length', 'B-core_product_type', 'O', 'O', 'B-UoM']
# 12818 ['Will', 'Leather', 'Goods', 'Brown', 'Wristlet', 'Clutch', 'Top', 'Zip', 'Closure', 'Boho', 'Style'] ['B-creator', 'I-creator', 'B-core_product_type', 'B-color', 'B-core_product_type', 'B-core_product_type', 'B-modifier', 'B-shape', 'I-shape', 'B-style', 'I-style']
# 12817 ['Hot', 'Cute', 'Japanese', 'Style', 'Blue', 'pink', 'Stripe', 'Panties', 'Bikini', 'Cosplay', 'Cotton', 'Underwear'] ['B-condition', 'B-modifier', 'B-origin', 'B-style', 'B-color', 'I-color', 'B-pattern', 'B-core_product_type', 'I-core_product_type', 'B-occasion', 'B-material', 'B-core_product_type']
# 12771 ['Dream', 'Pairs', 'Womens', 'Chunky', 'Platform', 'High', 'Heels', 'Closed', 'Toe', 'Block', 'Ankle', 'Strap', 'Dress'] ['B-creator', 'I-creator', 'B-department', 'B-modifier', 'B-core_product_type', 'B-feature', 'B-core_product_type', 'I-core_product_type', 'I-core_product_type', 'B-miniament', 'I-miniament', 'B-product_number', 'I-product_number']
# 12770 ['B2BODY', 'Womens', 'Panties', 'Comfortable', 'High', 'Waist', 'Tummy', 'Control', 'Briefs', 'Multi', 'Pack'] ['B-creator', 'B-department', 'B-core_product_type', 'B-modifier', 'B-feature', 'I-feature', 'B-quantity', 'I-quantity', 'B-material', 'B-color', 'B-quantity']
# 12768 ['Nike', 'Zoom', 'Rival', 'Sprint', 'Track', 'Spike', 'Hyper', 'Pink', 'Black', 'Laser', 'Orange', '35'] ['B-creator', 'B-product_name', 'I-product_name', 'B-core_product_type', 'I-core_product_type', 'B-feature', 'B-color', 'B-color', 'B-color', 'B-color', 'B-color', 'B-UoM']
# 12755 ['CERYIWER', 'Womens', 'Band', 'Tees', 'Short', 'Sleeve', 'Vintage', 'T', 'Shirts', 'Summer', 'Casual', 'Tops'] ['B-creator', 'B-department', 'B-category', 'I-category', 'B-color', 'B-color', 'B-time', 'B-product_type', 'B-product_type', 'B-color', 'B-core_product_type', 'B-category']
# 12748 ['Mastectomy', 'Breast', 'Form', 'Bra', 'Insert', 'Pads', 'Beige', 'M'] ['B-core_product_type', 'B-body_part', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'I-core_product_type', 'B-color', 'B-UoM']
# 12736 ['Generation', 'Y', 'Womens', 'Mid', 'Calf', 'Boots', 'Fur', 'Cuff', 'Trimming', 'Casual', 'Pull', 'on', 'Shoes'] ['B-creator', 'I-creator', 'B-department', 'B-modifier', 'B-sleeve', 'B-core_product_type', 'B-material', 'B-detail', 'B-occasion', 'B-feature', 'O', 'B-product_name', 'I-product_name']
# 12735 ['Chain', 'Coin', 'Purse', 'by', 'Anthropologie', 'in', 'Black', 'Womens', 'Size', 'M', 'L'] ['B-label_type', 'B-creator', 'B-product_name', 'I-product_name', 'B-department', 'O', 'B-color', 'B-department', 'B-UoM', 'I-UoM', 'I-UoM']
# 12734 ['SHUSUKUE', 'Round', 'Heart', 'Oval', 'Shape', 'Locket', 'Necklace', 'That', 'Holds', 'Pictures', '925', 'Sterling'] ['B-creator', 'B-shape', 'I-shape', 'I-shape', 'B-label_type', 'B-core_product_type', 'I-core_product_type', 'O', 'B-condition', 'B-occasion', 'B-material', 'B-condition']
# 12733 ['Frye', 'Supply', 'Womens', 'Safety', 'Crafted', 'Chelsea', 'Steel', 'Toe', 'Boot', 'FR40502F'] ['B-creator', 'B-occupation', 'B-department', 'B-condition', 'B-detail', 'B-label_type', 'B-feature', 'B-detail', 'B-color', 'B-product_number']
# 12732 ['Maternity', 'Sonoma', 'Goods', 'for', 'Life', 'Over', 'The', 'Belly', 'Jeggings', 'Womens', 'Size', '6', 'MAT', 'Blue'] ['B-modifier', 'B-creator', 'I-creator', 'O', 'B-core_product_type', 'B-occupation', 'I-occupation', 'I-occupation', 'B-core_product_type', 'B-department', 'B-UoM', 'I-UoM', 'B-modifier', 'B-color']
# 12731 ['Hde', 'Beach', 'Coverups', 'for', 'Women', 'UPF', '50', 'Long', 'Sleeve', 'Swim', 'Cover', 'Up', 'Dress', 'with', 'Hood'] ['B-creator', 'B-occasion', 'B-core_product_type', 'O', 'B-department', 'B-feature', 'B-feature', 'B-sleeve', 'B-product_name', 'B-label_type', 'I-label_type', 'B-color', 'B-detail', 'B-feature', 'B-feature']
# 12730 ['Chef', 'Uniforms', 'Womens', '1', 'Pocket', 'Long', 'Sleeve', 'w', 'Fabric', 'Covered', 'Buttons', 'Chef', 'Coat', 'in'] ['B-occupation', 'B-label_type', 'B-department', 'B-modifier', 'B-feature', 'B-sleeve', 'B-label_type', 'B-condition', 'B-material', 'B-detail', 'B-detail', 'B-product_name', 'I-product_name', 'O']
# 12729 ['New', 'Balance', 'Mens', 'Printed', 'Impact', 'Run', 'Short', 'Sleeve', 'Black', 'Size', 'S'] ['B-condition', 'B-creator', 'B-department', 'B-modifier', 'B-product_name', 'I-product_name', 'B-label_type', 'B-sleeve', 'B-color', 'B-UoM', 'I-UoM']
# 12728 ['FANCYHandFans', 'Designer', 'Hand', 'Fans', 'Buy', '4', 'Get', '5', 'Womens', 'Summer', 'Fashion', 'Accessory'] ['B-creator', 'B-creator', 'B-core_product_type', 'I-core_product_type', 'B-quantity', 'I-quantity', 'I-quantity', 'B-quantity', 'B-department', 'B-occasion', 'B-modifier', 'B-accessory']
# 12704 ['Iswee', 'Genuine', 'Leather', 'Shoulder', 'Bags', 'Purses', 'and', 'Handbags', 'for', 'Women', 'Top', 'Handle', 'Tote'] ['B-creator', 'B-condition', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'O', 'B-core_product_type', 'O', 'B-department', 'B-core_product_type', 'I-core_product_type', 'B-product_type']
# 12699 ['lululemon', 'athletica', 'Lululemon', 'Robert', 'Geller', 'Collaboration', 'Take', 'The', 'Moment'] ['B-creator', 'I-creator', 'B-creator', 'B-creator', 'I-creator', 'B-product_name', 'B-product_name', 'O', 'B-moment']
# 12698 ['Titanium', 'Internally', 'Threaded', 'Barbell', 'UrbanBodyJewelrycom', '16g', '3', '8', '10mm', '3mm'] ['B-material', 'B-material', 'B-condition', 'B-product_name', 'B-creator', 'B-UoM', 'B-quantity', 'I-quantity', 'B-dimension', 'B-dimension']
# 12697 ['NEKOSI', 'Womens', 'Long', 'Sleeve', 'V', 'Neck', 'Hoodie', 'Sweatshirts', 'Lightweight', 'Pullover', 'Tops'] ['B-creator', 'B-department', 'B-core_product_type', 'I-core_product_type', 'B-shape', 'B-neckline', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-wear', 'B-core_product_type']
# 12690 ['Amazon', 'Collection', 'Cubic', 'Zirconia', 'All', 'Around', 'Band', 'Stacking', 'Ring', 'Set'] ['B-creator', 'I-creator', 'B-material', 'I-material', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'B-modifier', 'B-core_product_type', 'B-set']
# ...
# 331 ['Luxury', 'Designer', 'The', 'Tote', 'Bag', 'for', 'Women', 'Large', 'Capacity', 'Leather', 'Handbags', 'Female'] ['B-price', 'B-creator', 'B-product_name', 'I-product_name', 'I-product_name', 'O', 'B-department', 'B-UoM', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-gender']
# 327 ['14K', 'Solid', 'Gold', 'Nose', 'Stud', 'Choose', 'from', '108', 'Options'] ['B-material', 'B-condition', 'B-material', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'O', 'B-quantity', 'B-options']
# 325 ['Eden', 'Olivia', 'Maternity', 'Top', 'Blue', 'Stripe', 'Button', 'Up', 'Long', 'Sleeve', 'Buttons'] ['B-creator', 'I-creator', 'B-intended_user', 'B-basic_feature', 'B-color', 'B-pattern', 'B-design_element', 'I-design_element', 'B-sleeve_style', 'B-sleeve_style', 'B-closure']
# 324 ['Nike', 'Zoom', 'Rival', 'Distance', 'Hyper', 'Pink', 'Black', 'Laser', 'Orange', 'M115', 'W13'] ['B-creator', 'B-product_name', 'I-product_name', 'B-activity', 'I-activity', 'B-color', 'B-color', 'B-color', 'I-color', 'B-UoM', 'I-UoM']
# 323 ['Colorful', 'Stacking', 'Gemstone', 'Rings', 'Set', 'of', '9', '5', '1', '2'] ['B-color', 'B-activity', 'B-modifier', 'B-core_product_type', 'B-quantity', 'O', 'I-quantity', 'B-UoM', 'I-UoM', 'I-UoM']
# 320 ['Womens', 'Maternity', 'Brown', 'Long', 'Sleeve', 'Basic', 'Crew', 'Neck', 'Fitted', 'T', 'Shirt', 'Size', '6'] ['B-department', 'B-intended_user', 'B-color', 'B-modifier', 'B-sleeve_style', 'B-basic_feature', 'B-neckline', 'I-neckline', 'B-fitting', 'B-base', 'I-base', 'B-UoM', 'I-UoM']
# 319 ['MKF', 'Collection', 'by', 'Mia', 'K', 'Valeria', 'Satchel', 'Handbag', 'with', 'Keyring', 'Grey'] ['B-creator', 'B-product_name', 'O', 'B-creator', 'I-creator', 'B-product_name', 'I-product_name', 'B-core_product_type', 'O', 'B-accessory', 'B-color']
# 317 ['Izod', 'Mens', 'Classic', 'Fit', 'Suit', 'Jackets', 'Black', 'Solid'] ['B-creator', 'B-department', 'B-modifier', 'I-modifier', 'B-core_product_type', 'I-core_product_type', 'B-color', 'B-pattern']
# 293 ['Moissanite', 'Stud', 'Earrings', 'Clip', 'on', 'Earrings', 'for', 'Non', 'Pierced', 'Ears', '18K', 'White', 'Gold'] ['B-content', 'B-product_name', 'I-product_name', 'B-modifier', 'O', 'B-product_name', 'O', 'B-condition', 'I-condition', 'B-part', 'B-UoM', 'B-color', 'I-color']
# 292 ['Wrangler', 'Authentics', 'Men’s', 'Comfort', 'Flex', 'Waistband', 'Jean', 'Short'] ['B-creator', 'B-product_name', 'B-department', 'B-modifier', 'I-modifier', 'B-part', 'B-product_name', 'I-product_name']
# 287 ['Pistola', 'Callista', 'Puffer', 'Jacket', 'with', 'Removable', 'Sleeves', 'in', 'Noir'] ['B-creator', 'B-product_name', 'I-product_name', 'B-core_product_type', 'O', 'B-modifier', 'B-part', 'O', 'B-color']
# 286 ['Belle', 'de', 'Mer', 'Cultured', 'Freshwater', 'Pearl', '5', '10mm', 'Graduated', '18', 'Strand', 'Necklace', 'in'] ['B-creator', 'I-creator', 'I-creator', 'B-material', 'I-material', 'I-material', 'B-UoM', 'B-UoM', 'B-modifier', 'B-length', 'B-set', 'B-core_product_type', 'O']
# 285 ['Cinderella', 'Divine', 'CD001', 'Formal', 'Peplum', 'Prom', 'Fitted', 'Long', 'Dress'] ['B-creator', 'B-creator', 'B-product_number', 'B-occasion', 'B-style', 'B-occasion', 'B-modifier', 'B-length', 'B-core_product_type']
# 281 ['Crazycatz', 'Womens', 'Bohemian', 'Block', 'Heels', 'Leather', 'Boots', 'Colorful', 'Leather', 'Ankle', 'Boots'] ['B-creator', 'B-department', 'B-style', 'I-style', 'B-core_product_type', 'B-material', 'B-core_product_type', 'B-color', 'I-material', 'B-origin', 'B-core_product_type']
# 278 ['boohoo', 'Maternity', 'Polo', 'Collar', 'Rib', 'Knit', 'Top', 'And', 'Maxi', 'Skirt', 'Matching', 'Set', 'Cream'] ['B-creator', 'B-department', 'B-product_name', 'I-product_name', 'B-material', 'I-material', 'B-core_product_type', 'O', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-set', 'B-color']
# 188 ['Bulova', 'Mens', 'Classic', 'Stainless', 'Steel', 'Bracelet', 'Watch', 'Silver'] ['B-creator', 'B-department', 'B-product_name', 'B-material', 'I-material', 'B-core_product_type', 'B-product_type', 'B-color']
# 165 ['18K', 'Yellow', 'Gold', 'Plated', 'Sterling', 'Silver', 'Genuine', 'Amethyst', 'and', 'Diamond', 'Accent'] ['B-attribute', 'B-color', 'B-material', 'I-material', 'B-material', 'B-material', 'B-content', 'B-content', 'O', 'B-color', 'B-core_product_type']
# 163 ['Kendra', 'Scott', 'Candice', 'Statement', 'Cuff', 'Bracelet', 'in', 'Vintage', 'Gold', 'Plated', 'Brass', 'Metal'] ['B-creator', 'I-creator', 'B-product_name', 'B-attribute', 'B-core_product_type', 'B-core_product_type', 'O', 'B-origin', 'B-color', 'B-material', 'I-material', 'I-material']
# 162 ['Luxe', 'Timepiece', 'Collection', '12', 'Slot', 'Saffiano', 'Leather', 'Watch', 'Box', 'Organizer', 'Luxury'] ['B-modifier', 'B-core_product_type', 'B-category_name', 'B-quantity', 'B-material', 'B-material', 'B-core_product_type', 'B-core_product_type', 'B-core_product_type', 'B-attribute', 'B-price']
# 160 ['Personalized', 'Multiple', 'Pictures', 'Photos', 'Customized', 'Gift', 'Custom', 'Phone', 'Case', 'for'] ['B-modifier', 'B-attribute', 'B-attribute', 'B-attribute', 'B-modifier', 'B-occasion', 'B-modifier', 'B-core_product_type', 'B-core_product_type', 'O']
# 159 ['Womens', 'Washable', 'Stretch', 'Silk', 'Shell', 'Tank', 'Top', 'in', 'Black', 'Size', 'Medium', 'Mulberry', 'Silk'] ['B-department', 'B-attribute', 'I-attribute', 'B-integration_phase', 'B-core_product_type', 'B-core_product_type', 'B-core_product_type', 'O', 'B-color', 'B-UoM', 'I-UoM', 'B-material', 'I-material']
# 158 ['GIA', 'Emerald', 'Cut', 'Diamond', '621', 'Carat', 'Great', 'Deal'] ['B-creator', 'B-attribute', 'I-attribute', 'B-original_core_product_base', 'B-product_number', 'B-UoM', 'B-attribute', 'B-attribute']
# 157 ['Zella', 'Other', 'Zella', 'Workout', 'Top', 'and', 'Bottom', 'Color', 'Gray', 'Size', 'Os', 'Olliehicks'] ['B-creator', 'B-other', 'I-creator', 'B-occasion', 'B-core_product_type', 'O', 'B-core_product_type', 'B-attribute', 'B-color', 'B-UoM', 'B-UoM', 'B-creator']
# 115 ['Huhot', 'Womens', 'Summer', 'Sundress', 'Sleeveless', 'Halter', 'Neck', 'Spring', 'Boho', 'Floral', 'with'] ['B-creator', 'B-department', 'B-time', 'B-core_product_type', 'I-core_product_type', 'B-modifier', 'B-shape', 'B-time', 'B-modifier', 'B-pattern', 'O']
# 114 ['Clovery', 'Womens', 'Sport', 'Wear', '2', 'Button', 'Polo', 'Short', 'Sleeve', 'Shirt'] ['B-creator', 'B-department', 'B-product_name', 'I-product_name', 'B-quantity', 'B-modifier', 'B-pattern', 'B-shape', 'B-shape', 'B-core_product_type']
# 113 ['Hermes', 'Birkin', '25', 'Himalaya', 'Niloticus', 'Crocodile', 'Diamond', 'Encrusted', 'Hardware'] ['B-creator', 'B-product_name', 'B-UoM', 'B-pattern', 'B-origin', 'B-material', 'B-modifier', 'I-modifier', 'B-material']
# 108 ['Cozy', 'Brushed', 'Cardigans', 'Animal', 'Medium'] ['B-modifier', 'B-material', 'B-core_product_type', 'B-pattern', 'B-UoM']
# 106 ['JASAMBAC', 'Women', '3', 'Piece', 'Rash', 'Guard', 'Long', 'Sleeve', 'Zip', 'Up', 'Swimsuits', 'with', 'Boyshort', 'UV'] ['B-creator', 'B-department', 'B-quantity', 'I-quantity', 'B-modifier', 'B-core_product_type', 'B-modifier', 'B-shape', 'I-shape', 'B-core_product_type', 'O', 'B-shape', 'I-product_type', 'B-condition']
# 85 ['Luxury', 'Divas', 'Pink', 'Plaid', 'Fleece', '3', 'Piece', 'Hat', 'Scarf', 'Glove', 'Matching', 'Set'] ['B-price', 'B-creator', 'B-color', 'B-pattern', 'B-material', 'B-quantity', 'I-quantity', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type', 'I-core_product_type', 'B-core_product_type']
# ([14836,
#   14826,
#   14825,
#   14824,
#   14823,
#   14822,
#   14821,
#   14820,
#   14804,
#   14787,
#   14780,
#   14778,
#   14767,
#   14766,
#   14765,
#   14762,
#   14758,
#   14756,
#   14739,
#   14735,
#   14697,
#   14696,
#   14695,
#   14694,
#   14693,
#   14692,
#   14670,
#   14598,
#   14592,
#   14573,
#   14451,
#   14428,
#   14339,
#   14334,
#   14331,
#   14322,
#   14321,
#   14319,
#   14318,
#   14316,
#   14315,
#   14239,
#   14227,
#   14222,
#   14219,
#   14216,
#   14212,
#   14211,
#   14210,
#   14209,
#   14208,
#   14207,
#   14206,
#   14205,
#   14204,
#   14160,
#   14156,
#   14072,
#   14070,
#   14068,
#   14065,
#   14064,
#   14063,
#   14062,
#   14060,
#   14059,
#   14058,
#   14055,
#   14050,
#   13991,
#   13972,
#   13964,
#   13963,
#   13962,
#   13958,
#   13947,
#   13912,
#   13909,
#   13908,
#   13889,
#   13874,
#   13872,
#   13870,
#   13868,
#   13836,
#   13653,
#   13647,
#   13627,
#   13582,
#   13476,
#   13466,
#   13458,
#   13457,
#   13452,
#   13417,
#   13416,
#   13415,
#   13414,
#   13413,
#   13411,
#   13410,
#   13408,
#   13407,
#   13278,
#   13277,
#   13168,
#   13164,
#   13122,
#   13109,
#   13108,
#   13107,
#   13105,
#   13101,
#   13094,
#   13093,
#   13062,
#   13049,
#   13048,
#   13047,
#   13046,
#   13045,
#   13044,
#   13040,
#   13038,
#   13037,
#   13036,
#   13033,
#   13032,
#   13021,
#   13020,
#   13019,
#   13017,
#   13015,
#   13013,
#   12981,
#   12980,
#   12972,
#   12891,
#   12890,
#   12889,
#   12888,
#   12887,
#   12886,
#   12885,
#   12884,
#   12883,
#   12882,
#   12871,
#   12870,
#   12868,
#   12866,
#   12862,
#   12855,
#   12818,
#   12817,
#   12771,
#   12770,
#   12768,
#   12755,
#   12748,
#   12736,
#   12735,
#   12734,
#   12733,
#   12732,
#   12731,
#   12730,
#   12729,
#   12728,
#   12704,
#   12699,
#   12698,
#   12697,
#   12690,
#   12688,
#   12648,
#   12590,
#   12589,
#   12586,
#   12585,
#   12584,
#   12583,
#   12582,
#   12565,
#   12561,
#   12554,
#   12538,
#   12527,
#   12503,
#   12502,
#   12499,
#   12490,
#   12489,
#   12487,
#   12485,
#   12484,
#   12483,
#   12466,
#   12451,
#   12437,
#   12434,
#   12411,
#   12410,
#   12407,
#   12406,
#   12405,
#   12404,
#   12403,
#   12380,
#   12378,
#   12376,
#   12367,
#   12357,
#   12343,
#   12342,
#   12341,
#   12339,
#   12338,
#   12337,
#   12336,
#   12334,
#   12283,
#   12280,
#   12273,
#   12272,
#   12270,
#   12269,
#   12236,
#   12173,
#   12172,
#   12167,
#   12159,
#   12158,
#   12134,
#   12127,
#   12094,
#   12073,
#   12068,
#   12065,
#   12064,
#   12052,
#   12051,
#   12049,
#   12048,
#   12004,
#   12003,
#   11968,
#   11943,
#   11934,
#   11929,
#   11914,
#   11910,
#   11887,
#   11886,
#   11884,
#   11850,
#   11848,
#   11843,
#   11842,
#   11840,
#   11820,
#   11817,
#   11815,
#   11813,
#   11812,
#   11811,
#   11787,
#   11765,
#   11750,
#   11749,
#   11748,
#   11745,
#   11731,
#   11702,
#   11701,
#   11700,
#   11697,
#   11696,
#   11695,
#   11691,
#   11690,
#   11663,
#   11656,
#   11654,
#   11653,
#   11652,
#   11651,
#   11650,
#   11648,
#   11647,
#   11614,
#   11612,
#   11610,
#   11609,
#   11608,
#   11607,
#   11606,
#   11605,
#   11584,
#   11583,
#   11582,
#   11581,
#   11580,
#   11578,
#   11577,
#   11576,
#   11566,
#   11555,
#   11554,
#   11553,
#   11550,
#   11548,
#   11547,
#   11492,
#   11475,
#   11474,
#   11468,
#   11466,
#   11436,
#   11415,
#   11414,
#   11412,
#   11411,
#   11410,
#   11409,
#   11408,
#   11357,
#   11356,
#   11355,
#   11349,
#   11342,
#   11334,
#   11333,
#   11327,
#   11322,
#   11321,
#   11269,
#   11265,
#   11219,
#   11218,
#   11217,
#   11216,
#   11214,
#   11185,
#   11156,
#   11139,
#   11137,
#   11134,
#   11061,
#   11050,
#   11049,
#   10979,
#   10899,
#   10898,
#   10896,
#   10892,
#   10864,
#   10853,
#   10851,
#   10846,
#   10844,
#   10814,
#   10811,
#   10808,
#   10776,
#   10775,
#   10774,
#   10773,
#   10772,
#   10771,
#   10769,
#   10767,
#   10735,
#   10570,
#   10538,
#   10389,
#   10375,
#   10370,
#   10355,
#   10346,
#   10321,
#   10287,
#   10262,
#   10260,
#   10249,
#   10248,
#   10247,
#   10246,
#   10245,
#   10244,
#   10243,
#   10242,
#   10191,
#   10185,
#   10183,
#   10166,
#   10121,
#   10120,
#   10118,
#   10113,
#   10112,
#   10102,
#   10097,
#   10011,
#   9934,
#   9893,
#   9892,
#   9891,
#   9890,
#   9882,
#   9881,
#   9880,
#   9878,
#   9876,
#   9875,
#   9874,
#   9859,
#   9811,
#   9809,
#   9806,
#   9802,
#   9795,
#   9773,
#   9772,
#   9771,
#   9770,
#   9769,
#   9768,
#   9767,
#   9766,
#   9765,
#   9744,
#   9680,
#   9663,
#   9655,
#   9603,
#   9601,
#   9598,
#   9597,
#   9594,
#   9582,
#   9578,
#   9560,
#   9494,
#   9434,
#   9425,
#   9403,
#   9398,
#   9397,
#   9396,
#   9384,
#   9383,
#   9381,
#   9378,
#   9364,
#   9314,
#   9313,
#   9312,
#   9311,
#   9310,
#   9309,
#   9308,
#   9307,
#   9306,
#   9305,
#   9304,
#   9303,
#   9302,
#   9301,
#   9299,
#   9298,
#   9297,
#   9296,
#   9295,
#   9254,
#   9249,
#   9197,
#   9196,
#   9193,
#   9191,
#   9142,
#   9130,
#   9101,
#   9100,
#   9098,
#   9077,
#   9068,
#   9067,
#   9065,
#   9064,
#   9063,
#   9062,
#   9061,
#   9060,
#   9046,
#   9045,
#   9044,
#   9041,
#   9038,
#   9029,
#   8960,
#   8958,
#   8953,
#   8951,
#   8928,
#   8923,
#   8902,
#   8900,
#   8899,
#   8897,
#   8895,
#   8880,
#   8878,
#   8877,
#   8876,
#   8856,
#   8838,
#   8822,
#   8816,
#   8808,
#   8806,
#   8773,
#   8772,
#   8771,
#   8770,
#   8769,
#   8768,
#   8767,
#   8765,
#   8760,
#   8741,
#   8696,
#   8655,
#   8608,
#   8607,
#   8606,
#   8605,
#   8604,
#   8601,
#   8600,
#   8586,
#   8569,
#   8509,
#   8504,
#   8498,
#   8497,
#   8496,
#   8494,
#   8399,
#   8389,
#   8335,
#   8318,
#   8314,
#   8243,
#   8242,
#   8241,
#   8240,
#   8239,
#   8238,
#   8237,
#   8236,
#   8235,
#   8228,
#   8177,
#   8164,
#   8162,
#   8117,
#   8115,
#   8111,
#   8110,
#   8101,
#   8054,
#   8023,
#   8020,
#   7871,
#   7867,
#   7863,
#   7829,
#   7827,
#   7822,
#   7820,
#   7819,
#   7816,
#   7813,
#   7801,
#   7800,
#   7799,
#   7797,
#   7796,
#   7795,
#   7794,
#   7771,
#   7770,
#   7769,
#   7768,
#   7766,
#   7763,
#   7746,
#   7732,
#   7730,
#   7729,
#   7728,
#   7727,
#   7726,
#   7724,
#   7679,
#   7649,
#   7646,
#   7645,
#   7644,
#   7643,
#   7631,
#   7625,
#   7572,
#   7571,
#   7564,
#   7555,
#   7529,
#   7527,
#   7526,
#   7517,
#   7516,
#   7489,
#   7488,
#   7473,
#   7472,
#   7471,
#   7470,
#   7469,
#   7468,
#   7467,
#   7334,
#   7332,
#   7331,
#   7329,
#   7266,
#   7260,
#   7220,
#   7177,
#   7176,
#   7175,
#   7172,
#   7171,
#   7170,
#   7168,
#   7156,
#   7117,
#   7116,
#   7111,
#   7109,
#   7055,
#   6986,
#   6981,
#   6947,
#   6945,
#   6944,
#   6942,
#   6941,
#   6940,
#   6938,
#   6937,
#   6935,
#   6934,
#   6932,
#   6931,
#   6920,
#   6906,
#   6899,
#   6878,
#   6876,
#   6874,
#   6873,
#   6872,
#   6871,
#   6869,
#   6832,
#   6778,
#   6776,
#   6720,
#   6718,
#   6714,
#   6713,
#   6708,
#   6685,
#   6683,
#   6650,
#   6649,
#   6648,
#   6631,
#   6629,
#   6627,
#   6574,
#   6571,
#   6570,
#   6566,
#   6554,
#   6550,
#   6549,
#   6544,
#   6543,
#   6542,
#   6541,
#   6540,
#   6539,
#   6538,
#   6537,
#   6535,
#   6495,
#   6491,
#   6490,
#   6486,
#   6482,
#   6480,
#   6474,
#   6456,
#   6455,
#   6454,
#   6450,
#   6449,
#   6447,
#   6376,
#   6286,
#   6248,
#   6247,
#   6236,
#   6188,
#   6180,
#   6147,
#   6138,
#   6136,
#   6107,
#   6084,
#   5958,
#   5950,
#   5948,
#   5947,
#   5944,
#   5943,
#   5940,
#   5934,
#   5910,
#   5909,
#   5908,
#   5907,
#   5906,
#   5905,
#   5904,
#   5903,
#   5902,
#   5901,
#   5889,
#   5799,
#   5798,
#   5769,
#   5766,
#   5763,
#   5738,
#   5734,
#   5709,
#   5670,
#   5666,
#   5663,
#   5661,
#   5657,
#   5651,
#   5602,
#   5601,
#   5596,
#   5568,
#   5567,
#   5564,
#   5563,
#   5532,
#   5522,
#   5520,
#   5519,
#   5517,
#   5516,
#   5515,
#   5512,
#   5511,
#   5509,
#   5507,
#   5506,
#   5505,
#   5433,
#   5428,
#   5373,
#   5371,
#   5370,
#   5369,
#   5354,
#   5353,
#   5349,
#   5342,
#   5340,
#   5326,
#   5323,
#   5317,
#   5289,
#   5180,
#   5166,
#   5066,
#   5064,
#   5045,
#   4998,
#   4987,
#   4984,
#   4983,
#   4982,
#   4981,
#   4977,
#   4968,
#   4960,
#   4958,
#   4957,
#   4956,
#   4955,
#   4954,
#   4953,
#   4952,
#   4951,
#   4950,
#   4932,
#   4898,
#   4890,
#   4886,
#   4878,
#   4875,
#   4849,
#   4846,
#   4843,
#   4839,
#   4834,
#   4775,
#   4759,
#   4756,
#   4695,
#   4614,
#   4612,
#   4609,
#   4607,
#   4593,
#   4586,
#   4562,
#   4556,
#   4554,
#   4552,
#   4551,
#   4548,
#   4547,
#   4546,
#   4545,
#   4544,
#   4540,
#   4539,
#   4537,
#   4526,
#   4522,
#   4458,
#   4457,
#   4456,
#   4453,
#   4450,
#   4449,
#   4447,
#   4396,
#   4381,
#   4236,
#   4233,
#   4227,
#   4224,
#   4219,
#   4218,
#   4217,
#   4216,
#   4215,
#   4213,
#   4212,
#   4211,
#   4207,
#   4206,
#   4205,
#   4204,
#   4203,
#   4198,
#   4187,
#   4169,
#   4168,
#   4167,
#   4164,
#   4149,
#   4148,
#   4146,
#   4145,
#   4143,
#   4142,
#   4141,
#   4019,
#   4016,
#   4015,
#   4014,
#   4012,
#   4010,
#   4009,
#   4006,
#   3991,
#   3981,
#   3980,
#   3974,
#   3973,
#   3971,
#   3970,
#   3968,
#   3967,
#   3966,
#   3964,
#   3963,
#   3911,
#   3909,
#   3908,
#   3905,
#   3842,
#   3841,
#   3840,
#   3839,
#   3836,
#   3833,
#   3830,
#   3802,
#   3787,
#   3771,
#   3743,
#   3742,
#   3733,
#   3649,
#   3645,
#   3616,
#   3603,
#   3599,
#   3444,
#   3441,
#   3440,
#   3402,
#   3387,
#   3370,
#   3352,
#   3342,
#   3265,
#   3253,
#   3252,
#   3251,
#   3238,
#   3237,
#   3236,
#   3235,
#   3232,
#   3158,
#   3140,
#   3110,
#   3108,
#   3102,
#   3094,
#   3091,
#   3089,
#   3088,
#   3087,
#   3085,
#   3084,
#   3058,
#   3043,
#   3042,
#   3038,
#   3037,
#   3023,
#   3011,
#   3009,
#   3008,
#   2981,
#   2949,
#   2947,
#   2913,
#   2884,
#   2882,
#   2881,
#   2880,
#   2877,
#   2835,
#   2796,
#   2773,
#   2768,
#   2763,
#   2762,
#   2761,
#   2757,
#   2735,
#   2730,
#   2728,
#   2715,
#   2714,
#   ...],
#  1248)

# %%
# Delete collected indices
for i in sorted(indices_to_delete, reverse=True):
    del data['tokens'][i]
    del data['ner_tags'][i]

# %%
len(data['tokens']), len(data['ner_tags'])
# Out:
# (13592, 13592)

# %%
from datasets import Dataset

dataset = Dataset.from_dict(data)

print(dataset)
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags'],
#     num_rows: 13592
# })

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bltlab/queryner-augmented-data-bert-base-uncased")

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, padding=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples["ner_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label_to_id[label[word_idx]])
            else:
                label_ids.append(label_to_id[label[word_idx]] if label_all_tokens else -100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

label_to_id = model.config.label2id
id_to_label = model.config.id2label

label_all_tokens = True

tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
# Out:
# Map:   0%|          | 0/13592 [00:00<?, ? examples/s]

# %%
tokenized_dataset
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 13592
# })

# %%
from torch.utils.data import DataLoader

train_size = 0.8
train_dataset = tokenized_dataset.train_test_split(train_size=train_size)["train"]
eval_dataset = tokenized_dataset.train_test_split(train_size=train_size)["test"]

print("Jumlah Training Data:", len(train_dataset))
print("Jumlah Testing Data:", len(eval_dataset))

train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=16)
eval_dataloader = DataLoader(eval_dataset, batch_size=16)
# Out:
# Jumlah Training Data: 10873
# Jumlah Testing Data: 2719

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer, pad_to_multiple_of=8)

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_labels = [[id_to_label[l] for l in label if l != -100] for label in labels]
    true_predictions = [
        [id_to_label[pred] for (pred, label) in zip(prediction, label) if label != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = precision_recall_fscore_support(
        [item for sublist in true_labels for item in sublist],
        [item for sublist in true_predictions for item in sublist],
        average='weighted'
    )
    
    precision, recall, f1, _ = results
    accuracy = accuracy_score(
        [item for sublist in true_labels for item in sublist],
        [item for sublist in true_predictions for item in sublist]
    )
    
    return {
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "accuracy": accuracy,
    }

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results-2",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=20,
    weight_decay=0.01
)

# %%
from transformers import AutoModelForTokenClassification, Trainer

model = AutoModelForTokenClassification.from_pretrained("bltlab/queryner-augmented-data-bert-base-uncased", num_labels=len(label_to_id))

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
#   0%|          | 0/13600 [00:00<?, ?it/s]
# {'loss': 1.5155, 'learning_rate': 1.9264705882352943e-05, 'epoch': 0.74}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 1.0135315656661987, 'eval_precision': 0.6977373043642959, 'eval_recall': 0.7025597853253006, 'eval_f1': 0.693733709955025, 'eval_accuracy': 0.7025597853253006, 'eval_runtime': 2.4905, 'eval_samples_per_second': 1091.744, 'eval_steps_per_second': 68.259, 'epoch': 1.0}
# {'loss': 1.1159, 'learning_rate': 1.8529411764705884e-05, 'epoch': 1.47}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.8889304995536804, 'eval_precision': 0.7360590818612222, 'eval_recall': 0.7368919523295888, 'eval_f1': 0.7303656041060735, 'eval_accuracy': 0.7368919523295888, 'eval_runtime': 2.407, 'eval_samples_per_second': 1129.628, 'eval_steps_per_second': 70.628, 'epoch': 2.0}
# {'loss': 1.0115, 'learning_rate': 1.7794117647058825e-05, 'epoch': 2.21}
# {'loss': 0.9401, 'learning_rate': 1.7058823529411767e-05, 'epoch': 2.94}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.8058589696884155, 'eval_precision': 0.7640030963588352, 'eval_recall': 0.7572018626187156, 'eval_f1': 0.7529022305044452, 'eval_accuracy': 0.7572018626187156, 'eval_runtime': 2.4108, 'eval_samples_per_second': 1127.862, 'eval_steps_per_second': 70.517, 'epoch': 3.0}
# {'loss': 0.8432, 'learning_rate': 1.6323529411764708e-05, 'epoch': 3.68}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.7264552712440491, 'eval_precision': 0.7826698835769622, 'eval_recall': 0.7795111941280156, 'eval_f1': 0.7779041368074918, 'eval_accuracy': 0.7795111941280156, 'eval_runtime': 2.4299, 'eval_samples_per_second': 1118.958, 'eval_steps_per_second': 69.961, 'epoch': 4.0}
# {'loss': 0.79, 'learning_rate': 1.558823529411765e-05, 'epoch': 4.41}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.6704097986221313, 'eval_precision': 0.7990944642038782, 'eval_recall': 0.7975322932835232, 'eval_f1': 0.7958897779780737, 'eval_accuracy': 0.7975322932835232, 'eval_runtime': 2.4034, 'eval_samples_per_second': 1131.303, 'eval_steps_per_second': 70.732, 'epoch': 5.0}
# {'loss': 0.7549, 'learning_rate': 1.485294117647059e-05, 'epoch': 5.15}
# {'loss': 0.6956, 'learning_rate': 1.4117647058823532e-05, 'epoch': 5.88}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.6222133636474609, 'eval_precision': 0.8181873781782751, 'eval_recall': 0.8145799900028939, 'eval_f1': 0.8136518045607438, 'eval_accuracy': 0.8145799900028939, 'eval_runtime': 2.3929, 'eval_samples_per_second': 1136.271, 'eval_steps_per_second': 71.043, 'epoch': 6.0}
# {'loss': 0.6378, 'learning_rate': 1.3382352941176471e-05, 'epoch': 6.62}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.5756256580352783, 'eval_precision': 0.8338897080956472, 'eval_recall': 0.8315487622004156, 'eval_f1': 0.8308648245427837, 'eval_accuracy': 0.8315487622004156, 'eval_runtime': 2.3859, 'eval_samples_per_second': 1139.612, 'eval_steps_per_second': 71.252, 'epoch': 7.0}
# {'loss': 0.6002, 'learning_rate': 1.2647058823529412e-05, 'epoch': 7.35}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.5442438721656799, 'eval_precision': 0.8473034087835993, 'eval_recall': 0.844018836652548, 'eval_f1': 0.8439194078795202, 'eval_accuracy': 0.844018836652548, 'eval_runtime': 2.4118, 'eval_samples_per_second': 1127.392, 'eval_steps_per_second': 70.488, 'epoch': 8.0}
# {'loss': 0.5763, 'learning_rate': 1.1911764705882354e-05, 'epoch': 8.09}
# {'loss': 0.5238, 'learning_rate': 1.1176470588235295e-05, 'epoch': 8.82}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.5160796046257019, 'eval_precision': 0.8569027650180252, 'eval_recall': 0.8540685591013127, 'eval_f1': 0.854398565252311, 'eval_accuracy': 0.8540685591013127, 'eval_runtime': 2.3874, 'eval_samples_per_second': 1138.879, 'eval_steps_per_second': 71.206, 'epoch': 9.0}
# {'loss': 0.5002, 'learning_rate': 1.0441176470588236e-05, 'epoch': 9.56}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.49238574504852295, 'eval_precision': 0.8641763849917247, 'eval_recall': 0.8625660992870485, 'eval_f1': 0.8623987949497548, 'eval_accuracy': 0.8625660992870485, 'eval_runtime': 2.4331, 'eval_samples_per_second': 1117.521, 'eval_steps_per_second': 69.871, 'epoch': 10.0}
# {'loss': 0.4633, 'learning_rate': 9.705882352941177e-06, 'epoch': 10.29}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.47492605447769165, 'eval_precision': 0.8727201153339721, 'eval_recall': 0.8702217779063955, 'eval_f1': 0.8705317544992416, 'eval_accuracy': 0.8702217779063955, 'eval_runtime': 2.4162, 'eval_samples_per_second': 1125.302, 'eval_steps_per_second': 70.357, 'epoch': 11.0}
# {'loss': 0.4553, 'learning_rate': 8.970588235294119e-06, 'epoch': 11.03}
# {'loss': 0.416, 'learning_rate': 8.23529411764706e-06, 'epoch': 11.76}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.4616265594959259, 'eval_precision': 0.8779706157881195, 'eval_recall': 0.8764568151324617, 'eval_f1': 0.8766779297246974, 'eval_accuracy': 0.8764568151324617, 'eval_runtime': 2.3838, 'eval_samples_per_second': 1140.634, 'eval_steps_per_second': 71.316, 'epoch': 12.0}
# {'loss': 0.4, 'learning_rate': 7.500000000000001e-06, 'epoch': 12.5}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.4547128975391388, 'eval_precision': 0.8821485598093108, 'eval_recall': 0.881192286443398, 'eval_f1': 0.8812492622885513, 'eval_accuracy': 0.881192286443398, 'eval_runtime': 2.4093, 'eval_samples_per_second': 1128.523, 'eval_steps_per_second': 70.559, 'epoch': 13.0}
# {'loss': 0.3835, 'learning_rate': 6.764705882352942e-06, 'epoch': 13.24}
# {'loss': 0.3661, 'learning_rate': 6.029411764705883e-06, 'epoch': 13.97}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.448445200920105, 'eval_precision': 0.8855586370205087, 'eval_recall': 0.8837441793165136, 'eval_f1': 0.884021726279918, 'eval_accuracy': 0.8837441793165136, 'eval_runtime': 2.3718, 'eval_samples_per_second': 1146.373, 'eval_steps_per_second': 71.675, 'epoch': 14.0}
# {'loss': 0.3437, 'learning_rate': 5.294117647058824e-06, 'epoch': 14.71}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.43842557072639465, 'eval_precision': 0.889661903357026, 'eval_recall': 0.8887427323669465, 'eval_f1': 0.8888684328077475, 'eval_accuracy': 0.8887427323669465, 'eval_runtime': 2.3646, 'eval_samples_per_second': 1149.88, 'eval_steps_per_second': 71.894, 'epoch': 15.0}
# {'loss': 0.3321, 'learning_rate': 4.558823529411765e-06, 'epoch': 15.44}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.4354954659938812, 'eval_precision': 0.8922514194499249, 'eval_recall': 0.8910841598484649, 'eval_f1': 0.8912066043644814, 'eval_accuracy': 0.8910841598484649, 'eval_runtime': 2.3803, 'eval_samples_per_second': 1142.315, 'eval_steps_per_second': 71.421, 'epoch': 16.0}
# {'loss': 0.3287, 'learning_rate': 3.8235294117647055e-06, 'epoch': 16.18}
# {'loss': 0.3142, 'learning_rate': 3.0882352941176476e-06, 'epoch': 16.91}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.4352060854434967, 'eval_precision': 0.8936467242931346, 'eval_recall': 0.8921364868064507, 'eval_f1': 0.8923961202327251, 'eval_accuracy': 0.8921364868064507, 'eval_runtime': 2.3919, 'eval_samples_per_second': 1136.748, 'eval_steps_per_second': 71.073, 'epoch': 17.0}
# {'loss': 0.2993, 'learning_rate': 2.3529411764705885e-06, 'epoch': 17.65}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.42990612983703613, 'eval_precision': 0.895391134401538, 'eval_recall': 0.8944779142879693, 'eval_f1': 0.8946284616800805, 'eval_accuracy': 0.8944779142879693, 'eval_runtime': 2.3991, 'eval_samples_per_second': 1133.364, 'eval_steps_per_second': 70.861, 'epoch': 18.0}
# {'loss': 0.2962, 'learning_rate': 1.6176470588235297e-06, 'epoch': 18.38}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.43129420280456543, 'eval_precision': 0.8959000574089153, 'eval_recall': 0.8948462287232644, 'eval_f1': 0.8950082102165087, 'eval_accuracy': 0.8948462287232644, 'eval_runtime': 2.3882, 'eval_samples_per_second': 1138.503, 'eval_steps_per_second': 71.183, 'epoch': 19.0}
# {'loss': 0.2919, 'learning_rate': 8.823529411764707e-07, 'epoch': 19.12}
# {'loss': 0.2855, 'learning_rate': 1.4705882352941178e-07, 'epoch': 19.85}
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.43035760521888733, 'eval_precision': 0.8963330078172799, 'eval_recall': 0.8953723922022573, 'eval_f1': 0.8955302587068306, 'eval_accuracy': 0.8953723922022573, 'eval_runtime': 2.395, 'eval_samples_per_second': 1135.259, 'eval_steps_per_second': 70.98, 'epoch': 20.0}
# {'train_runtime': 1070.9557, 'train_samples_per_second': 203.052, 'train_steps_per_second': 12.699, 'train_loss': 0.5712658513293547, 'epoch': 20.0}
# TrainOutput(global_step=13600, training_loss=0.5712658513293547, metrics={'train_runtime': 1070.9557, 'train_samples_per_second': 203.052, 'train_steps_per_second': 12.699, 'train_loss': 0.5712658513293547, 'epoch': 20.0})

# %%
import matplotlib.pyplot as plt

# Extract loss values
train_loss = []
eval_loss = []

for log in trainer.state.log_history:
    if 'loss' in log:
        train_loss.append(log['loss'])
    if 'eval_loss' in log:
        eval_loss.append(log['eval_loss'])

# Plotting the training and evaluation loss
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Training Loss')
plt.plot(eval_loss, label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Loss over Epochs')
plt.legend()
plt.grid()
plt.show()

# %%
results = trainer.evaluate()
print(results)
# Out:
#   0%|          | 0/170 [00:00<?, ?it/s]
# {'eval_loss': 0.43035760521888733, 'eval_precision': 0.8963330078172799, 'eval_recall': 0.8953723922022573, 'eval_f1': 0.8955302587068306, 'eval_accuracy': 0.8953723922022573, 'eval_runtime': 2.6937, 'eval_samples_per_second': 1009.403, 'eval_steps_per_second': 63.111, 'epoch': 20.0}

# %%
# Extract metrics
train_loss = []
eval_loss = []
eval_precision = []
eval_recall = []
eval_f1 = []
eval_accuracy = []
epochs = []

for log in trainer.state.log_history:
    if 'loss' in log:
        train_loss.append(log['loss'])
        epochs.append(log['epoch'])
    if 'eval_loss' in log:
        eval_loss.append(log['eval_loss'])
    if 'eval_precision' in log:
        eval_precision.append(log['eval_precision'])
    if 'eval_recall' in log:
        eval_recall.append(log['eval_recall'])
    if 'eval_f1' in log:
        eval_f1.append(log['eval_f1'])
    if 'eval_accuracy' in log:
        eval_accuracy.append(log['eval_accuracy'])

# Plotting the metrics
plt.figure(figsize=(14, 10))

# Plot loss
plt.subplot(2, 1, 1)
plt.plot(epochs[:len(train_loss)], train_loss, label='Training Loss')
plt.plot(epochs[:len(eval_loss)], eval_loss, label='Evaluation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Loss over Epochs')
plt.legend()
plt.grid()

# Plot evaluation metrics
plt.subplot(2, 1, 2)
plt.plot(epochs[:len(eval_precision)], eval_precision, label='Precision')
plt.plot(epochs[:len(eval_recall)], eval_recall, label='Recall')
plt.plot(epochs[:len(eval_f1)], eval_f1, label='F1 Score')
plt.plot(epochs[:len(eval_accuracy)], eval_accuracy, label='Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.title('Evaluation Metrics over Epochs')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
finetuned_ner = "queryner-ft-20"
trainer.save_model(finetuned_ner)
tokenizer.save_pretrained(finetuned_ner)
# Out:
# ('queryner-ft-20\\tokenizer_config.json',
#  'queryner-ft-20\\special_tokens_map.json',
#  'queryner-ft-20\\vocab.txt',
#  'queryner-ft-20\\added_tokens.json',
#  'queryner-ft-20\\tokenizer.json')

# %%
from transformers import AutoModelForTokenClassification

non_finetuned_model = AutoModelForTokenClassification.from_pretrained("bltlab/queryner-augmented-data-bert-base-uncased", num_labels=len(label_to_id))
non_finetuned_trainer = Trainer(
    model=non_finetuned_model,
    args=training_args,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

# %%
non_finetuned_results = non_finetuned_trainer.evaluate()
print("Non-finetuned model results:", non_finetuned_results)
# Out:
# 100%|██████████| 170/170 [00:05<00:00, 28.58it/s]
# Non-finetuned model results: {'eval_loss': 5.979460716247559, 'eval_precision': 0.3954540275889737, 'eval_recall': 0.31065073181004527, 'eval_f1': 0.31465119736261105, 'eval_accuracy': 0.31065073181004527, 'eval_runtime': 6.1984, 'eval_samples_per_second': 438.663, 'eval_steps_per_second': 27.427}

# %%
#pretty print the results and non_finetuned_results
import pprint
pp = pprint.PrettyPrinter()
pp.pprint(results)
pp.pprint(non_finetuned_results)
# Out:
# {'epoch': 3.0,
#  'eval_accuracy': 0.7293092555543856,
#  'eval_f1': 0.7225485904852819,
#  'eval_loss': 0.9295413494110107,
#  'eval_precision': 0.7272749053745428,
#  'eval_recall': 0.7293092555543856,
#  'eval_runtime': 6.0037,
#  'eval_samples_per_second': 452.887,
#  'eval_steps_per_second': 28.316}
# {'eval_accuracy': 0.31065073181004527,
#  'eval_f1': 0.31465119736261105,
#  'eval_loss': 5.979460716247559,
#  'eval_precision': 0.3954540275889737,
#  'eval_recall': 0.31065073181004527,
#  'eval_runtime': 6.1984,
#  'eval_samples_per_second': 438.663,
#  'eval_steps_per_second': 27.427}

# %%
# save the fine-tuned model
finetuned_ner = "queryner-augmented-data-bert-base-uncased-finetuned"
trainer.save_model(finetuned_ner)
tokenizer.save_pretrained(finetuned_ner)
# Out:
# ('queryner-augmented-data-bert-base-uncased-finetuned\\tokenizer_config.json',
#  'queryner-augmented-data-bert-base-uncased-finetuned\\special_tokens_map.json',
#  'queryner-augmented-data-bert-base-uncased-finetuned\\vocab.txt',
#  'queryner-augmented-data-bert-base-uncased-finetuned\\added_tokens.json',
#  'queryner-augmented-data-bert-base-uncased-finetuned\\tokenizer.json')

# %% [markdown]
# # Train Ulang

# %%
import pandas as pd
twitter = pd.read_csv('twt_queries.csv', usecols=['product', 'created_at']) 
twitter.dropna(subset=['product'], inplace=True)
twitter.head(10)
print(len(twitter))
# Out:
# 4857

# %%
import pandas as pd
gt = pd.read_csv('gt_queries.csv', usecols=['product', 'ts']) 
gt.dropna(subset=['product'], inplace=True)
gt.head(10)
# Out:
#                          product        ts
# 0                NFL Team Jersey  8/1/2024
# 1               NFL Game Tickets  8/1/2024
# 2                   NFL Logo Hat  8/1/2024
# 3     Fantasy Football Draft Kit  8/1/2024
# 4  NFL Collectible Trading Cards  8/1/2024
# 5             Olympic Golf Balls  8/1/2024
# 6           Olympic Golf T-Shirt  8/1/2024
# 7               Olympic Golf Hat  8/1/2024
# 8                 Golf Clubs Set  8/1/2024
# 9                    Golf Gloves  8/1/2024

# %%
finetuned_ner = "queryner-augmented-data-bert-base-uncased-finetuned"

model = AutoModelForTokenClassification.from_pretrained(finetuned_ner)
tokenizer = AutoTokenizer.from_pretrained(finetuned_ner)

# %%
# Define blacklist categories
black_list_categories = {
    "core_product_type": ["'", "s",  "g", "br", "-", "with"],
    "modifier": ["with", "for"],
    "department": ["for", "cur", "ho", "with"],
    "occasion": ["for", "br", "s", "to", "with"],
    "shape": ["with", "-", "tu", "with"],
    "material": ["for", "br", "s", "to", "with"],
    "color": ["skate", "with", "colors", "color"],
    "creator": ["'", "s", "-", "with"],
    "UoM": ["for", "br", "s", "to", "with"],
    "price": ["on", "with"],
    "product_name": ["y", "'", "s", "t", "g", "br", "-", "with"],
    "content": ["for", "br", "s", "to", "with"],
    "condition": ["for", "br", "s", "to", "with"],
    "quantity": ["for", "br", "s", "to", "with"],
    "origin": ["for", "br", "s", "to", "with"],
    "time": ["for", "br", "s", "to", "with"],
}

def get_entities_from_model_output(text, tokenizer, model, score_threshold=0.15):
    inputs = tokenizer(text, return_tensors="pt")
    tokens = inputs.tokens()

    with torch.no_grad():
        outputs = model(**inputs).logits

    predictions = torch.argmax(outputs, dim=2)
    scores = torch.softmax(outputs, dim=2).max(dim=2).values

    label_map = model.config.id2label
    entities = []

    for token, pred, score in zip(tokens, predictions[0], scores[0]):
        label = label_map[pred.item()]
        if label != "O" and score.item() > score_threshold:
            entities.append({
                "entity": label,
                "score": score.item(),
                "token": token
            })

    return entities

def post_process_entities(entities):
    processed_entities = []
    current_entity = None

    for token_info in entities:
        token, label, score = token_info["token"], token_info["entity"], token_info["score"]

        if token in ["[CLS]", "[SEP]"]:
            continue 

        if token.startswith("##"):
            if current_entity is not None:
                current_entity["score"] = min(current_entity["score"], score)
                current_entity["word"] += token[2:]

                # Update entity to non-modifier if necessary
                if label[2:] != "modifier" and current_entity["entity"] == "modifier":
                    current_entity["entity"] = label[2:]
        else:
            if current_entity is not None:
                processed_entities.append(current_entity)
            current_entity = {
                "entity": label[2:],  # Remove the B- or I- prefix
                "score": score,
                "word": token,
            }

    if current_entity:
        processed_entities.append(current_entity)

    return processed_entities
    
def filter_entities(entities, black_list_categories):
    filtered_entities = []
    for entity in entities:
        if entity['word'] not in black_list_categories.get(entity['entity'], []):
            filtered_entities.append(entity)
    return filtered_entities

def process_ner(texts, model, tokenizer, score_threshold=0.15):
    results = []
    for text in tqdm(texts, total=len(texts),  desc="Processing NER"):
        raw_entities = get_entities_from_model_output(text, tokenizer, model, score_threshold=score_threshold)
        processed_entities = post_process_entities(raw_entities)
        filtered_entities = filter_entities(processed_entities, black_list_categories)
        results.append(filtered_entities)
    return results

# %%
titles = twitter['product'].tolist()
ner_results = process_ner(titles, model=model, tokenizer=tokenizer)
# Out:
# Processing NER: 100%|██████████| 4857/4857 [03:31<00:00, 22.95it/s]

# %%
def get_each_category_value(entity_results, category):
    categories = []
    for entities in entity_results:
        category_values = []
        for entity in entities:
            if entity["entity"] == category:
                category_values.append(entity["word"])
        if category_values:
            categories.append(category_values)
        else:
            categories.append([])
    return categories

output = get_each_category_value(ner_results, "core_product_type")
print(output)
# Out:
# [['dresses'], ['dresses'], ['dresses'], ['dresses'], ['dresses'], [], ['accessories'], ['jewelry'], ['decor', 'items'], ['decorations'], ['packages'], ['song', 'playlists'], ['books'], ['t', 'shirt'], ['merchandise'], ['apparel'], ['shoulder', 'top'], ['skirt'], ['high', 'heels'], ['makeup', 'kit'], ['beauty', 'filter'], ['t', 'shirts'], ['prints'], ['magazines'], ['accessories'], [], ['outfit'], ['skin', 'customization'], ['accessories'], ['photo', 'editing', 'software'], ['merchandise'], ['accessories'], ['products'], ['dress'], ['kurta'], [], [], ['accessories'], ['gift', 'boxes'], ['gift', 'packaging'], ['gift', 'boxes'], [], [], ['kurta', 'sets'], ['cards'], ['home', 'decor'], ['magazine'], ['merchandise'], ['records'], ['art', 'prints'], [], ['luggage'], ['carry', 'on', 'bags'], ['accessories'], ['clothing'], ['outfit'], ['guide'], ['book'], ['art', 'tickets'], ['accessories'], ['clothing'], ['music', 'video', 'dvd'], ['t', 'shirts'], ['wear'], ['guitar', 'picks'], ['art', 'prints'], ['books'], ['accessories'], ['tickets'], ['shoes'], ['sole', 'shoes'], ['tabio', 'socks'], ['socks'], ['raincoat'], ['items'], ['footwear'], ['accessories'], ['saddle', 'bag'], [], ['handbag'], ['crossbody', 'bags'], ['clothing'], ['prints'], ['merchandise'], ['apparel'], ['t', 'shirt'], ['hair', 'claw'], ['props'], ['outfits'], ['clothing'], ['hats'], ['lighting', 'equipment'], ['dress'], ['prints'], ['sketching'], [], ['blazer'], ['belt'], ['jumpsuit'], ['hat'], ['sandals'], [], [], ['accessories'], ['merchandise'], ['sneakers'], ['makeup', 'kit'], [], ['jewelry'], ['bangles'], ['highlighter'], ['lipstick', 'set'], ['makeup', 'brush'], ['makeup', 'remover'], ['hair', 'accessories'], [], ['hijabs'], ['tops'], ['hijab', 'outfits'], ['pants'], ['sneakers'], [], ['course'], ['clothing'], ['photo', 'editing', 'software'], [], ['book'], ['photography', 'collection'], [], ['photography', 'equipment'], ['outfit'], ['balloon', 'decorations'], ['leis'], ['hats', 'crowns'], ['clothing'], ['outfits'], ['hair', 'accessories'], ['beauty', 'products'], ['pajamas'], ['bikini', 'set'], ['hat'], ['bag'], ['photo', 'props'], ['saree'], ['saree'], ['saree'], ['jewelry'], ['dress'], ['merchandise'], ['accessories'], ['spinner', 'wheel'], ['apparel'], ['streetwear'], ['outfits'], ['items'], ['hair', 'dye'], ['makeup'], ['blazer'], ['accessories'], ['merchandise'], ['nail', 'art', 'stickers'], ['nail', 'stickers'], ['nail', 'art', 'decals'], ['sunglasses'], ['photography', 'tutorials'], ['clothing'], ['camera', 'accessories'], ['prints'], ['rings'], ['necklaces'], ['bracelets'], ['jewellery', 'sets'], ['bracelets'], ['handbag'], ['dress'], ['accessories'], ['eyemakeup'], ['backdrop'], ['jeans'], ['t', 'shirts'], ['makeup', 'brushes'], ['merchandise'], ['apparel'], ['art', 'prints'], ['accessories'], ['tickets'], [], [], [], [], [], [], [], ['fabrics'], [], [], [], ['jewelry'], ['photo', 'album'], ['figurines'], ['photo', 'frame'], ['outfits'], ['makeup', 'products'], ['makeup', 'brushes'], ['hair', 'accessories', ')'], ['body', 'lot', 'products'], ['jewelry', 'necklaces', 'earrings'], ['makeup', 'palettes'], ['skincare', 'products'], ['nail', 'polish', 'nail', 'kits'], ['clothing', 'dresses'], ['gown'], ['merchandise'], ['artwork', 'prints'], ['sunglasses'], ['heels'], ['tickets'], ['dress'], ['tote', 'bag'], ['sandals'], ['jacket'], ['accessories'], ['costume'], ['banana', 'accessories'], ['art', 'prints'], ['books'], ['dress'], ['earrings'], ['beauty', 'products'], ['magazines'], [], [], ['jeans'], ['outfits'], ['jackets'], ['sneakers'], ['accessories'], ['t', 'shirts'], ['jeans'], ['camera'], ['books'], ['photography', 'equipment'], ['lighting', 'kit'], ['props'], ['book'], ['photography', 'print'], ['medallion', 'bag'], ['medallion', 'bag'], ['medallion', 'bag'], ['swimwear'], ['accessories'], ['backdrops'], [], ['dress'], ['heeled', 'sandals'], ['outfits'], ['dresses'], ['apparel'], ['clothing'], ['accessories'], ['coffee', 'drink', 'prop'], ['skin', 'makeu ...

# %%
entity_categories = set()
for entities in ner_results:
    for entity in entities:
        entity_categories.add(entity["entity"])

entity_category_counts = {category: 0 for category in entity_categories}
for entities in ner_results:
    for entity in entities:
        entity_category_counts[entity["entity"]] += 1

entity_category_counts = {k: v for k, v in sorted(entity_category_counts.items(), key=lambda item: item[1], reverse=True)}
entity_category_counts
# Out:
# {'core_product_type': 5768,
#  'modifier': 3057,
#  'creator': 1674,
#  'department': 1143,
#  'occasion': 902,
#  'product_name': 866,
#  'color': 402,
#  'material': 393,
#  'content': 173,
#  'time': 132,
#  'origin': 129,
#  'quantity': 98,
#  'UoM': 98,
#  'condition': 92,
#  'shape': 67,
#  'product_number': 30,
#  'price': 14}

# %%
for category in entity_category_counts.keys():
    output = get_each_category_value(ner_results, category)
    twitter[category] = output

# %%
twitter.T.head(20)
# Out:
#                                              0     \
# product                              maxi dresses
# created_at         Fri Jun 23 11:11:13 +0000 2023
# core_product_type                       [dresses]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                        [maxi]
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              1     \
# product                           bodycon dresses
# created_at         Fri Jun 23 11:11:13 +0000 2023
# core_product_type                       [dresses]
# modifier                                       []
# creator                                 [bodycon]
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              2     \
# product                              wrap dresses
# created_at         Fri Jun 23 11:11:13 +0000 2023
# core_product_type                       [dresses]
# modifier                                   [wrap]
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              3     \
# product                         plus size dresses
# created_at         Fri Jun 23 11:11:13 +0000 2023
# core_product_type                       [dresses]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                  [plus, size]
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4     \
# product                              boho dresses
# created_at         Fri Jun 23 11:11:13 +0000 2023
# core_product_type                       [dresses]
# modifier                                   [boho]
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              5     \
# product                traditional Indian lehenga
# created_at         Fri Jun 23 12:53:21 +0000 2023
# core_product_type                              []
# modifier                            [traditional]
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                            [lehenga]
# content                                        []
# origin                                   [indian]
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              6     \
# product                       wedding accessories
# created_at         Fri Jun 23 12:53:21 +0000 2023
# core_product_type                   [accessories]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                [wedding]
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              7     \
# product                        bridal jewelry set
# created_at         Fri Jun 23 12:53:21 +0000 2023
# core_product_type                       [jewelry]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                 [bridal]
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                    [set]
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              8     \
# product                       wedding decor items
# created_at         Fri Jun 23 12:53:21 +0000 2023
# core_product_type                  [decor, items]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                [wedding]
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              9     ...  \
# product                   dance floor decorations  ...
# created_at         Fri Jun 23 12:53:21 +0000 2023  ...
# core_product_type                   [decorations]  ...
# modifier                                       []  ...
# creator                                        []  ...
# department                                     []  ...
# occasion                           [dance, floor]  ...
# color                                          []  ...
# material                                       []  ...
# product_name                                   []  ...
# content                                        []  ...
# origin                                         []  ...
# UoM                                            []  ...
# time                                           []  ...
# condition                                      []  ...
# quantity                                       []  ...
# shape                                          []  ...
# product_number                                 []  ...
# price                                          []  ...
#
#                                              4868  \
# product                          Hijab Outfit Set
# created_at         Mon Feb 13 12:12:20 +0000 2023
# core_product_type                 [hijab, outfit]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                    [set]
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4869  \
# product                         designer clothing
# created_at         Sat Feb 11 03:06:40 +0000 2023
# core_product_type                      [clothing]
# modifier                               [designer]
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4870  \
# product                       fashion accessories
# created_at         Sat Feb 11 03:06:40 +0000 2023
# core_product_type                   [accessories]
# modifier                                [fashion]
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4871  \
# product                       photo shoot outfits
# created_at         Sat Feb 11 03:06:40 +0000 2023
# core_product_type                       [outfits]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                           [photo, shoot]
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4872  \
# product                                  lingerie
# created_at         Sat Feb 11 03:06:40 +0000 2023
# core_product_type                      [lingerie]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4873  \
# product                              luxury robes
# created_at         Sat Feb 11 03:06:40 +0000 2023
# core_product_type                         [robes]
# modifier                                 [luxury]
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                                  4874  \
# product            buy one get one free winter blouse
# created_at             Sun Feb 12 14:42:21 +0000 2023
# core_product_type                            [blouse]
# modifier                                           []
# creator                                            []
# department                                         []
# occasion                                           []
# color                                              []
# material                                           []
# product_name                                       []
# content                                            []
# origin                                             []
# UoM                                                []
# time                                         [winter]
# condition                                          []
# quantity                                           []
# shape                                              []
# product_number                                     []
# price                                     [buy, free]
#
#                                              4875  \
# product                       winter fashion tops
# created_at         Sun Feb 12 14:42:21 +0000 2023
# core_product_type                          [tops]
# modifier                                [fashion]
# creator                                        []
# department                                     []
# occasion                                       []
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                     [winter]
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4876  \
# product                   seasonal women's shirts
# created_at         Sun Feb 12 14:42:21 +0000 2023
# core_product_type                        [shirts]
# modifier                                       []
# creator                                        []
# department                          [women, ', s]
# occasion                               [seasonal]
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                          []
#
#                                              4877
# product                  discount winter clothing
# created_at         Sun Feb 12 14:42:21 +0000 2023
# core_product_type                      [clothing]
# modifier                                       []
# creator                                        []
# department                                     []
# occasion                                 [winter]
# color                                          []
# material                                       []
# product_name                                   []
# content                                        []
# origin                                         []
# UoM                                            []
# time                                           []
# condition                                      []
# quantity                                       []
# shape                                          []
# product_number                                 []
# price                                  [discount]
#
# [19 rows x 4857 columns]

# %%
gt.columns
# Out:
# Index(['product', 'ts', 'core_product_type', 'modifier', 'creator',
#        'department', 'occasion', 'color', 'material', 'product_name',
#        'content', 'origin', 'UoM', 'time', 'condition', 'quantity', 'shape',
#        'product_number', 'price'],
#       dtype='object')

# %%
gt.to_csv('gt_queries_ner.csv', index=False)

# %%
twitter.to_csv('twt_queries_ner.csv', index=False)
